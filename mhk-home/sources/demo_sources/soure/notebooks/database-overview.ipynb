# %% [markdown]
# # Database overview notebook

# %% [markdown]
# > First time use: follow instructions in the README.md file in this directory.

# %% [markdown]
# ## Setup

# %%
from timelink.mhk.utilities import get_engine, get_dbnames, get_connection_string
from sqlalchemy import engine, text, MetaData
import platform

machine = platform.node()

print(f'Available databases at {machine}:')
print(get_dbnames())
#%load_ext sql
#%config SqlMagic.displaycon=False
# Out:
# Available databases at imac-jrc.local:
# ['china_coimbra', 'soure_ipm', 'ucprosop']

# %% [markdown]
# ## Connect to database

# %% [markdown]
# ### Choose the database

# %%
if machine == 'joaquims-mbpr.local':
    db = 'soure_editor'
elif machine == 'imac-jrc.local':
    db = 'soure_ipm'

connection_string = get_connection_string(db)
engine = get_engine(db)

# %% [markdown]
# ## Database status

# %%
with engine.connect() as connection:
    classes = connection.execute(
        text('select class,count(*) as n from entities group by class')
    )
    classes
for c in classes:
    print(c['class'],c.n)
# Out:
# act 10844
# acta 97
# acusacoes 315
# aforamento 2
# aregister 5
# attribute 65441
# cartaperdao 2
# caso 40
# class 27
# crime 1
# divida 3
# escritura 243
# geoentity 9
# good 6
# group_element 10870
# item 92
# object 2
# person 51438
# relation 86656
# rperson 1051
# source 184

# %% [markdown]
# ## Map MHK database

# %%
from sqlalchemy import Column,String,Integer,DateTime, ForeignKey
from sqlalchemy.orm import declarative_base, relationship

Base = declarative_base()

# %% [markdown]
# ## Entities
#
#         |-----------|--------------|------|-----|---------------------+-----------------------------+
#         | Field     | Type         | Null | Key | Default             | Extra                       |
#         +-----------+--------------+------+-----+---------------------+-----------------------------+
#         | id        | varchar(64)  | NO   | PRI | NULL                |                             |
#         | class     | varchar(64)  | YES  | MUL | NULL                |                             |
#         | inside    | varchar(64)  | YES  | MUL | NULL                |                             |
#         | the_order | decimal(6,0) | YES  |     | NULL                |                             |
#         | the_level | decimal(6,0) | YES  |     | NULL                |                             |
#         | the_line  | decimal(6,0) | YES  |     | NULL                |                             |
#         | groupname | varchar(32)  | YES  | MUL | NULL                |                             |
#         | updated   | timestamp    | NO   | MUL | CURRENT_TIMESTAMP   | on update CURRENT_TIMESTAMP |
#         | indexed   | timestamp    | NO   | MUL | 1974-04-25 00:00:01 |                             |
#         +-----------+--------------+------+-----+---------------------+-----------------------------+

# %%
from sqlalchemy import case

class Entity(Base):
    __tablename__ = 'entities'

    id = Column(String, primary_key=True)
    pom_class = Column('class',String,ForeignKey('classes.id'))
    inside = Column(String, ForeignKey('entities.id'))
    the_order = Column(Integer)
    the_level = Column(Integer)
    the_line = Column(Integer)
    groupname = Column(String)
    updated = Column(DateTime)
    indexed = Column(DateTime)


    rels_in = relationship("Relation", back_populates="dest")
    rels_out = relationship("Relation",back_populates="org")

    # see https://docs.sqlalchemy.org/en/14/orm/inheritance.html
    # To handle non mapped pom_class see https://github.com/sqlalchemy/sqlalchemy/issues/5445
    #
    #    __mapper_args__ = {
    #       "polymorphic_identity": "entity",
    #    "polymorphic_on": case(
    #        [(type.in_(["parent", "child"]), type)], else_="entity"
    #    ),
    # 
    #  This defines what mappings do exist
    # [aclass.__mapper_args__['polymorphic_identity'] for aclass in Entity.__subclasses__()]

    __mapper_args__ = {
        'polymorphic_identity': 'entity',
        'polymorphic_on':case(
            [(pom_class.in_(['attribute', 'relation', 'person', 'object', 'act', 'source', 'class']), pom_class)], 
                else_="entity")
    }

    # untested
    @classmethod  # untested
    def get_subclasses(cls):
        for subclass in cls.__subclasses__():
            yield from subclass.get_subclasses()
            yield subclass

    @classmethod 
    def mapped_pom_classes(cls):
        return [aclass.__mapper_args__['polymorphic_identity'] 
                    for aclass 
                    in Entity.__subclasses__()]

    @classmethod
    def table_to_orm(cls):
        """
        Return a dict with table name as key and ORM class as value
        """
        return {subclass.__mapper__.local_table.name:subclass for subclass in cls.get_subclasses()}


    @classmethod
    def pom_class_to_orm(cls):
        """
        Return a dict with pom_class as key and ORM class as valu
        """
        return {subclass.__mapper__.polymorphic_identity:subclass for subclass in cls.get_subclasses()}


    @classmethod
    def get_orm_for_table(cls,table: String):
        """
        Entity.get_orm_for_table("acts")

        will return the ORM class handling the "acts" table
        """
        return cls.table_to_orm().get(table,None)

    @classmethod
    def get_orm_for_pom_class(cls,pom_class: String):
        """
        Entity.get_orgm_for_pom_class("act")

        will return the ORM class corresponding to the pom_class "act" 
        """
        return cls.pom_class_to_orm().get(pom_class,None)
    

    def __repr__(self):
        return (
            f'Entity(id="{self.id}", '
            f'pom_class="{self.pom_class}",'
            f'inside="{self.inside}", '
            f'the_order={self.the_order}, '
            f'the_level={self.the_level}, '
            f'the_line={self.the_line}, '
            f'groupname="{self.groupname}", '
            
            f'updated={self.updated}, '
            f'indexed={self.indexed},'
            f')'
        )
        
    def __str__(self):
        return (f'{self.groupname}${self.id}/type={self.pom_class}')

# %% [markdown]
# ## Attributes
#     +-----------+----------------+------+-----+---------+-------+
#     | Field     | Type           | Null | Key | Default | Extra |
#     +-----------+----------------+------+-----+---------+-------+
#     | id        | varchar(64)    | NO   | PRI | NULL    |       |
#     | entity    | varchar(64)    | YES  | MUL | NULL    |       |
#     | the_type  | varchar(512)   | YES  | MUL | NULL    |       |
#     | the_value | varchar(1024)  | YES  | MUL | NULL    |       |
#     | the_date  | varchar(24)    | YES  | MUL | NULL    |       |
#     | obs       | varchar(16000) | YES  |     | NULL    |       |
#     +-----------+----------------+------+-----+---------+-------+

# %%
class Attribute(Entity):
    __tablename__ = 'attributes'

    id = Column(String, ForeignKey('entities.id'), primary_key=True)
    entity = Column(String,ForeignKey('entities.id'))
    the_type = Column(String)
    the_value = Column(String)
    the_date = Column(String)
    obs = Column(String)

    the_entity = relationship("Entity",foreign_keys=[entity],back_populates="attributes",)

    __mapper_args__ = {
        'polymorphic_identity':'attribute',     
        'inherit_condition': id == Entity.id
    }

    def __repr__(self):
        sr = super().__repr__()
        return (
            f'Attribute(id={sr}, '
            f'entity="{self.entity}", '
            f'the_type="{self.the_type}", '
            f'the_value="{self.the_value}", '
            f'the_date="{self.the_date}"", '
            f'obs={self.obs}'
            f')'
        )

    def __str__(self):
        r = f'     ls${self.the_type}/{self.the_value}/{self.the_date}'
        if self.obs is not None:
                r = (f'{r}/obs={self.obs}')
        return r


Entity.attributes = relationship("Attribute", foreign_keys=[Attribute.entity], back_populates="the_entity")

# %% [markdown]
# ## Relations
#     +-------------+----------------+------+-----+---------+-------+
#     | Field       | Type           | Null | Key | Default | Extra |
#     +-------------+----------------+------+-----+---------+-------+
#     | id          | varchar(64)    | NO   | PRI | NULL    |       |
#     | origin      | varchar(64)    | YES  | MUL | NULL    |       |
#     | destination | varchar(64)    | YES  | MUL | NULL    |       |
#     | the_date    | varchar(24)    | YES  | MUL | NULL    |       |
#     | the_type    | varchar(32)    | YES  | MUL | NULL    |       |
#     | the_value   | varchar(256)   | YES  | MUL | NULL    |       |
#     | obs         | varchar(16000) | YES  |     | NULL    |       |
#     +-------------+----------------+------+-----+---------+-------+

# %%
class Relation(Entity):  # should extend Entity but gives error

    __tablename__ = 'relations'

    id = Column(String,ForeignKey('entities.id'), primary_key=True)
    #rel_entity = relationship("Entity",foreign_keys='id',back_populates='rel')
    origin = Column(String,ForeignKey('entities.id'))
    org = relationship(Entity,foreign_keys=[origin], back_populates='rels_out')

    destination = Column(String,ForeignKey('entities.id'))
    dest = relationship("Entity",foreign_keys=[destination], back_populates="rels_in")
    the_type = Column(String)
    the_value = Column(String)
    the_date = Column(String)
    obs = Column(String)

    __mapper_args__ = {
        'polymorphic_identity':'relation',
        'inherit_condition': id == Entity.id
    }

    def __repr__(self):
        sr = super().__repr__()
        return (
            f'Relation(id={sr}, '
            f'origin="{self.origin}", '
            f'destination="{self.destination}", '
            f'the_type="{self.the_type}", '
            f'the_value="{self.the_value}", '
            f'the_date="{self.the_date}"", '
            f'obs={self.obs}'
            f')'
        )

    def __str__(self):
        if self.dest is not None and self.dest.pom_class == 'person':
            r = f'rel${self.the_type}/{self.the_value}/{self.dest.name}/{self.destination}/{self.the_date}'
        else:
            r = f'rel${self.the_type}/{self.the_value}/{self.destination}/{self.the_date}'
        if self.obs is not None:
                r = (f'{r}  /obs={self.obs}')
        return r

Entity.rels_out = relationship("Relation",foreign_keys=[Relation.origin],back_populates="dest")
Entity.rels_in = relationship("Relation",foreign_keys=[Relation.destination],back_populates="org")
# Out:
# /var/folders/6m/_0n598297cj_bc2ql0rynnx00000gp/T/ipykernel_89793/3788928658.py:44: SAWarning: Property Entity.rels_out on mapped class Entity->entities being replaced with new property Entity.rels_out; the old property will be discarded
#   Entity.rels_out = relationship("Relation",foreign_keys=[Relation.origin],back_populates="dest")
# /var/folders/6m/_0n598297cj_bc2ql0rynnx00000gp/T/ipykernel_89793/3788928658.py:44: SAWarning: Property Entity.rels_out on mapped class Attribute->attributes being replaced with new property Entity.rels_out; the old property will be discarded
#   Entity.rels_out = relationship("Relation",foreign_keys=[Relation.origin],back_populates="dest")
# /var/folders/6m/_0n598297cj_bc2ql0rynnx00000gp/T/ipykernel_89793/3788928658.py:44: SAWarning: Property Entity.rels_out on mapped class Relation->relations being replaced with new property Entity.rels_out; the old property will be discarded
#   Entity.rels_out = relationship("Relation",foreign_keys=[Relation.origin],back_populates="dest")
# /var/folders/6m/_0n598297cj_bc2ql0rynnx00000gp/T/ipykernel_89793/3788928658.py:45: SAWarning: Property Entity.rels_in on mapped class Entity->entities being replaced with new property Entity.rels_in; the old property will be discarded
#   Entity.rels_in = relationship("Relation",foreign_keys=[Relation.destination],back_populates="org")
# /var/folders/6m/_0n598297cj_bc2ql0rynnx00000gp/T/ipykernel_89793/3788928658.py:45: SAWarning: Property Entity.rels_in on mapped class Attribute->attributes being replaced with new property Entity.rels_in; the old property will be discarded
#   Entity.rels_in = relationship("Relation",foreign_keys=[Relation.destination],back_populates="org")
# /var/folders/6m/_0n598297cj_bc2ql0rynnx00000gp/T/ipykernel_89793/3788928658.py:45: SAWarning: Property Entity.rels_in on mapped class Relation->relations being replaced with new property Entity.rels_in; the old property will be discarded
#   Entity.rels_in = relationship("Relation",foreign_keys=[Relation.destination],back_populates="org")

# %% [markdown]
# ## Persons
#     +-------+----------------+------+-----+---------+-------+
#     | Field | Type           | Null | Key | Default | Extra |
#     +-------+----------------+------+-----+---------+-------+
#     | id    | varchar(64)    | NO   | PRI | NULL    |       |
#     | name  | varchar(128)   | YES  | MUL | NULL    |       |
#     | sex   | char(1)        | YES  |     | NULL    |       |
#     | obs   | varchar(16000) | YES  |     | NULL    |       |
#     +-------+----------------+------+-----+---------+-------+

# %%
class Person(Entity):
    __tablename__ = 'persons'

    id = Column(String, ForeignKey('entities.id'), primary_key=True)
    name = Column(String)
    sex = Column(String(1))
    obs = Column(String)

    __mapper_args__ = {
        'polymorphic_identity':'person'
    }

    def __repr__(self):
        sr = super().__repr__()
        return (
            f'Person(id={sr}, '
            f'name="{self.name}", '
            f'sex="{self.sex}", '
            f'obs={self.obs}'
            f')'
        )

        
    def __str__(self):
        r = f'{self.groupname}${self.name}/{self.sex}/id={self.id}'
        if self.obs is not None:
                r = (f'{r}  /obs={self.obs}')
        return r

# %% [markdown]
# ## Objects
#
#     +----------+----------------+------+-----+---------+-------+
#     | Field    | Type           | Null | Key | Default | Extra |
#     +----------+----------------+------+-----+---------+-------+
#     | id       | varchar(64)    | NO   | PRI | NULL    |       |
#     | name     | varchar(64)    | YES  | MUL | NULL    |       |
#     | the_type | varchar(32)    | YES  |     | NULL    |       |
#     | obs      | varchar(16000) | YES  |     | NULL    |       |
#     +----------+----------------+------+-----+---------+-------+

# %%
class Object(Entity):
    __tablename__ = 'objects'

    id = Column(String, ForeignKey('entities.id'), primary_key=True)
    name = Column(String)
    the_type = Column(String(32))
    obs = Column(String)

    __mapper_args__ = {
        'polymorphic_identity':'object'
    }

    def __repr__(self):
        sr = super().__repr__()
        return(
            f'Object(id={sr}, '
            f'name="{self.name}", '
            f'the_type="{self.the_type}", '
            f'obs={self.obs}'
            f')'
        )

    def __str__(self):
        r = f'{self.groupname}${self.name}/{self.the_type}/id={self.id}'
        if self.obs is not None:
                r = (f'{r}  /obs={self.obs}')
        return r

# %% [markdown]
# ## Acts
#
#     +----------+----------------+------+-----+---------+-------+
#     | Field    | Type           | Null | Key | Default | Extra |
#     +----------+----------------+------+-----+---------+-------+
#     | id       | varchar(64)    | NO   | PRI | NULL    |       |
#     | the_type | varchar(32)    | YES  |     | NULL    |       |
#     | the_date | varchar(24)    | YES  | MUL | NULL    |       |
#     | loc      | varchar(64)    | YES  |     | NULL    |       |
#     | ref      | varchar(64)    | YES  |     | NULL    |       |
#     | obs      | varchar(16000) | YES  |     | NULL    |       |
#     +----------+----------------+------+-----+---------+-------+

# %%
class Act(Entity):
    __tablename__ = 'acts'

    id = Column(String, ForeignKey('entities.id'), primary_key=True)
    the_type = Column(String(32))
    the_date = Column(String)
    loc = Column(String)
    ref = Column(String)
    obs = Column(String)

    __mapper_args__ = {
        'polymorphic_identity':'act'
    }


    def __repr__(self):
        sr = super().__repr__()
        return (
            f'Act(id={sr}, '
            f'the_type="{self.the_type}", '
            f'the_date="{self.the_date}", '
            f'local="{self.loc}", '
            f'ref="{self.ref}", '
            f'obs={self.obs}'
            f')'
            )

    def __str__(self):
        r = f'{self.groupname}${self.id}/{self.the_date}/type={self.the_type}/ref={self.ref}/loc={self.loc}'
        if self.obs is not None:
                r = (f'{r}  /obs={self.obs}')
        return r

# %% [markdown]
# ## Sources
#
#     +-----------+----------------+------+-----+---------+-------+
#     | Field     | Type           | Null | Key | Default | Extra |
#     +-----------+----------------+------+-----+---------+-------+
#     | id        | varchar(64)    | NO   | PRI | NULL    |       |
#     | the_type  | varchar(32)    | YES  |     | NULL    |       |
#     | the_date  | varchar(24)    | YES  |     | NULL    |       |
#     | loc       | varchar(64)    | YES  |     | NULL    |       |
#     | ref       | varchar(64)    | YES  |     | NULL    |       |
#     | kleiofile | varchar(1024)  | YES  |     | NULL    |       |
#     | replaces  | varchar(254)   | YES  |     | NULL    |       |
#     | obs       | varchar(16000) | YES  |     | NULL    |       |
#     +-----------+----------------+------+-----+---------+-------+

# %%
class Source(Entity):
    __tablename__ = 'sources'

    id = Column(String, ForeignKey('entities.id'), primary_key=True)
    the_type = Column(String(32))
    the_date = Column(String)
    loc = Column(String)
    ref = Column(String)
    kleiofile = Column(String)
    replaces = Column(String)
    obs = Column(String)

    __mapper_args__ = {
        'polymorphic_identity':'source'
    }

    def __repr__(self):
        sr = super().__repr__()
        return (
            f'Source(id={sr}, '
            f'the_type="{self.the_type}", '
            f'the_date="{self.the_date}", '
            f'local="{self.loc}", '
            f'ref="{self.ref}", '
            f'kleiofile="{self.kleiofile}", '
            f'replaces="{self.replaces}", '
            f'obs={self.obs}'
            f')'
        )

    def __str__(self):
        r = f'{self.groupname}${self.id}/{self.the_date}/type={self.the_type}/ref={self.ref}/loc={self.loc}/kleiofile={self.kleiofile}/replaces={self.replaces}'
        if self.obs is not None:
                r = (f'{r}  /obs={self.obs}')
        return r

# %% [markdown]
# ## POM Classes
#
#     +------------+-------------+------+-----+---------+-------+
#     | Field      | Type        | Null | Key | Default | Extra |
#     +------------+-------------+------+-----+---------+-------+
#     | id         | varchar(64) | NO   | PRI | NULL    |       |
#     | table_name | varchar(32) | YES  |     | NULL    |       |
#     | group_name | varchar(32) | YES  |     | NULL    |       |
#     | super      | varchar(64) | YES  |     | NULL    |       |
#     +------------+-------------+------+-----+---------+-------+

# %%
from typing import Optional

class PomSomMapper(Entity):
    __tablename__ = 'classes'

    id = Column(String, ForeignKey('entities.id'), primary_key=True)
    table_name = Column(String)
    class_group = Column("group_name",String(32))
    super_class = Column("super", String)

    __mapper_args__ = {
        'polymorphic_identity':'class',
        'inherit_condition': id == Entity.id
    }

    def ensure_mapping(self,session):
        """
        Ensure that a table exists to support this class.

        Checks in the metadata object if there is a table definition for this table.
        NOT TESTED
        """
        metadata_obj = type(self).metadata
        pytables = metadata_obj.tables
        if self.table_name in pytables.keys():
            return pytables[self.table_name]
        else:
            NewTable: Table = Table(self.table_name,metadata_obj,extend_existing=True)
            cattr: PomClassAttributes
            for cattr in self.class_attributes:
                PyType = None
                pom_type = cattr.coltype.lower()
                if pom_type == 'varchar':
                    PyType = String(cattr.colsize)
                elif pom_type == 'numeric' and cattr.colprecision == 0 :
                    PyType = Integer
                elif pom_type == 'numeric' and cattr.colprecision > 0:
                    PyType = Float
                else:
                    PyType = String
                print(f"Inferred python type for {cattr.colname}: ",PyType)

                print("Getting super class "+self.super_class)
                PomSuperClass: PomSomMapper = PomSomMapper.get_pom_class(session, self.super_class)
                if PomSuperClass is not None:
                    super_class_table_id = PomSuperClass.table_name+'.id'
                else:
                    print("ERROR coould not find superclass: ",self.super_class)
                    super_class_table_id = 'entities.id'
                if cattr.pkey != 0:
                    NewTable.append_column(Column(cattr.colname,PyType,ForeignKey(super_class_table_id), primary_key=True),replace_existing=True)
                else:
                    NewTable.append_column(Column(cattr.colname,PyType,primary_key=False),replace_existing=True)

            MyORM = Entity.get_orm_for_pom_class(self.id)       
            SuperORM = Entity.get_orm_for_pom_class(self.super_class)
            props = {
                '__table__': NewTable,
                '__mapper_args__':{'polymorphic_identity':self.id}
            }

            newORM = type(self.id.capitalize(),(SuperORM,),props)            
            #print("----")
            #print(repr(NewTable))
            #self.__table__= NewTable

    @classmethod
    def get_pom_class(cls,session, pom_class_name: String):
        """
        Return the pom_class object for a given pom_class_name.

        See also Entity.get_orm_for_pom_class

        """
        pom_class: Optional["PomSomMapper"] = session.query(Entity).get(pom_class_name)
        return pom_class

    def __repr__(self):
        return (
            f'PomSomMapper(id="{self.id}", '
            f'table_name="{self.table_name}", '
            f'class_group="{self.class_group}", '
            f'super_class="{self.super_class}" '
            f')'
        )

    def __str__(self):
        r = f'{self.id} table {self.table_name} super {self.super_class}\n'
        for cattr in self.class_attributes:
            r = r + f'{cattr.the_class}.{cattr.name} \tclass {cattr.colclass} \tcol {cattr.colname} \ttype {cattr.coltype} size {cattr.colsize} precision {cattr.colprecision} primary key {cattr.pkey} \n'
        return r

# %% [markdown]
# ## Class attributes
#
#     +--------------+--------------+------+-----+---------+-------+
#     | Field        | Type         | Null | Key | Default | Extra |
#     +--------------+--------------+------+-----+---------+-------+
#     | the_class    | varchar(64)  | YES  | MUL | NULL    |       |
#     | name         | varchar(32)  | YES  |     | NULL    |       |
#     | colname      | varchar(32)  | YES  |     | NULL    |       |
#     | colclass     | varchar(32)  | YES  |     | NULL    |       |
#     | coltype      | varchar(32)  | YES  |     | NULL    |       |
#     | colsize      | decimal(5,0) | YES  |     | NULL    |       |
#     | colprecision | decimal(6,0) | YES  |     | NULL    |       |
#     | pkey         | decimal(1,0) | YES  |     | NULL    |       |
#     +--------------+--------------+------+-----+---------+-------+

# %%
class PomClassAttributes(Base):
    __tablename__ = 'class_attributes'

    the_class = Column(String, ForeignKey('classes.id'),primary_key=True)
    
    pom_class = relationship("PomSomMapper",foreign_keys=[the_class], back_populates='class_attributes')
    name = Column(String(32), primary_key=True)
    colname = Column(String(32))
    colclass = Column(String(32))
    coltype = Column(String)
    colsize = Column(Integer)
    colprecision = Column(Integer)
    pkey = Column(Integer)

    def __repr__(self):
        return (
            f'PomClassAttributes(the_class="{self.the_class}", '
            f'name="{self.name}", '
            f'colname="{self.colname}", '
            f'colclass="{self.colclass}", '
            f'coltype="{self.coltype}", '
            f'colsize="{self.colsize}", '
            f'colprecision="{self.colprecision}", '
            f'pkey="{self.pkey}" '
            f')'
        )


PomSomMapper.class_attributes = relationship("PomClassAttributes", back_populates="pom_class")

# %%
from timelink.kleio.groups import KGroup

for gn in [(g._name,g) for g in KGroup.all_subclasses()]:
    print(gn)
# Out:
# ('kleio', <class 'timelink.kleio.groups.KKleio'>)
# ('source', <class 'timelink.kleio.groups.KSource'>)
# ('act', <class 'timelink.kleio.groups.KAct'>)
# ('person', <class 'timelink.kleio.groups.KPerson'>)
# ('object', <class 'timelink.kleio.groups.KAbstraction'>)
# ('object', <class 'timelink.kleio.groups.KObject'>)
# ('ls', <class 'timelink.kleio.groups.KLs'>)
# ('atr', <class 'timelink.kleio.groups.KAtr'>)
# ('attr', <class 'timelink.kleio.groups.KAttribute'>)
# ('rel', <class 'timelink.kleio.groups.KRelation'>)

# %% [markdown]
# ## Testing

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ### Attributes

# %%
attribute = session.query(Attribute).where(Entity.pom_class  == 'attribute').first()
print(attribute)
print(repr(attribute))
# Out:
#      ls$residencia/barrosas/16970205/obs=%barrosos.
# Attribute(id=Entity(id="$c51-2-att3-12", pom_class="attribute",inside="$c51-2", the_order=164, the_level=5, the_line=136, groupname="ls", updated=2021-08-21 08:33:00, indexed=1974-04-25 00:00:01,), entity="$c51-2", the_type="residencia", the_value="barrosas", the_date="16970205"", obs=%barrosos. )

# %%
entity = attribute.the_entity
print(entity)
# Out:
# pnoivo$domingos andre/m/id=$c51-2

# %% [markdown]
# ### Relations

# %%
relation = session.query(Relation).where(Relation.pom_class  == 'relation').first()

print(repr(relation))
print(relation)
# Out:
# Relation(id=Entity(id="$c51-2-att2-2-geo-rel", pom_class="relation",inside="$c51-2-att2-2-geo", the_order=None, the_level=None, the_line=None, groupname="*georelation", updated=2020-02-26 21:55:45, indexed=1974-04-25 00:00:01,), origin="$c51-2-att2-2-geo", destination="$c51-2", the_type="geografica", the_value="residencia", the_date="16970205"", obs=*automatic relation)
# rel$geografica/residencia/domingos andre/$c51-2/16970205  /obs=*automatic relation

# %%
relation = session.query(Relation).where(Relation.the_type  == 'parentesco').first()
print(repr(relation))

print(relation.org)
print("   ",relation)
print(relation.dest)
# Out:
# Relation(id=Entity(id="01705-a5e-rel17-4", pom_class="relation",inside="01705-a5e", the_order=274, the_level=5, the_line=331, groupname="rel", updated=2021-11-06 09:21:08, indexed=1974-04-25 00:00:01,), origin="01705-a5e", destination="1705-a5ea", the_type="parentesco", the_value="foi mulher", the_date="17051005"", obs=None)
# referida$maria fernandes/f/id=01705-a5e
#     rel$parentesco/foi mulher/manuel cordeiro/1705-a5ea/17051005
# referido$manuel cordeiro/m/id=1705-a5ea

# %% [markdown]
# ### Acts

# %%
act = session.query(Act).where(Entity.pom_class  == 'act').first()

print(repr(act))
print(act)
# Out:
# Act(id=Entity(id="1700-142", pom_class="act",inside="casamentos 1700", the_order=2, the_level=2, the_line=6, groupname="cas", updated=2020-06-17 18:18:21, indexed=2020-06-17 18:18:21,), the_type="cas", the_date="17000110", local="luis alvares pinto", ref="igreja matriz", obs=None)
# cas$1700-142/17000110/type=cas/ref=igreja matriz/loc=luis alvares pinto

# %% [markdown]
# ### Sources

# %%
source = session.query(Source).where(Entity.pom_class  == 'source').first()

print(repr(source))
print(source)
# Out:
# Source(id=Entity(id="1D-8-2-4", pom_class="source",inside="root", the_order=1, the_level=1, the_line=4, groupname="fonte", updated=2021-11-02 11:06:17, indexed=1974-04-25 00:00:01,), the_type="livro de notas", the_date="16910314", local="AUC D-8-2-4", ref="None", kleiofile="/kleio-home/sources/soure-fontes/sources/1685-1720/notariais/1D-8-2-4.cli", replaces="n2.23", obs=legivel)
# fonte$1D-8-2-4/16910314/type=livro de notas/ref=None/loc=AUC D-8-2-4/kleiofile=/kleio-home/sources/soure-fontes/sources/1685-1720/notariais/1D-8-2-4.cli/replaces=n2.23  /obs=legivel

# %% [markdown]
# ### Persons

# %%
from sqlalchemy import select

stmt = select(Person).where(Person.pom_class  == 'person').limit(1)
print(stmt)
result = session.execute(stmt)
person = result.scalars().all()[0]
print(person)
# Out:
# SELECT entities.class, persons.id, entities.id AS id_1, entities.inside, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.updated, entities.indexed, CASE WHEN (entities.class IN ([POSTCOMPILE_class_1])) THEN entities.class ELSE :param_1 END AS _sa_polymorphic_on, persons.name, persons.sex, persons.obs
# FROM entities JOIN persons ON entities.id = persons.id
# WHERE entities.class = :class_2
#  LIMIT :param_2
# pnoivo$domingos andre/m/id=$c51-2

# %%
from sqlalchemy import select,text

stmt = select(text(' id from classes'))
print(stmt)
result = session.execute(stmt)
ids = result.scalars().all()
print(ids)
# Out:
# SELECT  id from classes
# ['act', 'acta', 'acusacoes', 'aforamento', 'attribute', 'cartaperdao', 'caso', 'class', 'crime', 'divida', 'entity', 'escritura', 'geoentity', 'geometry', 'good', 'group_element', 'item', 'lgraph', 'object', 'person', 'relation', 'rentity', 'rgeoentity', 'robject', 'rperson', 'source']

# %% [markdown]
# ### PomSomMapper (table classes)

# %%
pom_classes = session.query(PomSomMapper).where(Entity.pom_class  == 'class').all()
for pom_class in pom_classes:
    print(repr(pom_class))
    print(pom_class)
# Out:
# PomSomMapper(id="act", table_name="acts", class_group="historical-act", super_class="entity" )
# act table acts
# act.date 	class date 	col the_date 	type varchar size 24 precision 0 primary key 0
# act.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# act.loc 	class loc 	col loc 	type varchar size 64 precision 0 primary key 0
# act.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# act.ref 	class ref 	col ref 	type varchar size 64 precision 0 primary key 0
# act.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# PomSomMapper(id="acta", table_name="actas", class_group="amz", super_class="act" )
# acta table actas
# acta.ano 	class year 	col the_year 	type numeric size 4 precision 0 primary key 0
# acta.dia 	class day 	col the_day 	type numeric size 2 precision 0 primary key 0
# acta.fol 	class fol 	col fol 	type varchar size 64 precision 0 primary key 0
# acta.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# acta.mes 	class month 	col the_month 	type numeric size 2 precision 0 primary key 0
# acta.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# acta.resumo 	class resumo 	col resumo 	type varchar size 1024 precision 0 primary key 0
#
# PomSomMapper(id="acusacoes", table_name="acusacoes", class_group="acusa", super_class="object" )
# acusacoes table acusacoes
# acusacoes.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# acusacoes.idcaso 	class idcaso 	col idcaso 	type varchar size 64 precision 0 primary key 0
# acusacoes.literal 	class literal 	col literal 	type varchar size 16000 precision 0 primary key 0
# acusacoes.obs 	class obs 	col obs 	type varchar size 16000 precision 0 primary key 0
# acusacoes.origem 	class origem 	col origem 	type varchar size 16000 precision 0 primary key 0
#
# PomSomMapper(id="aforamento", table_name="aforamentos", class_group="aforamento", super_class="good" )
# aforamento table aforamentos
# aforamento.description 	class description 	col description 	type varchar size 1024 precision 0 primary key 0
# aforamento.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# aforamento.loc 	class loc 	col loc 	type varchar size 64 precision 0 primary key 0
# aforamento.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# aforamento.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# aforamento.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# PomSomMapper(id="attribute", table_name="attributes", class_group="attribute", super_class="entity" )
# attribute table attributes
# attribute.date 	class date 	col the_date 	type varchar size 24 precision 0 primary key 0
# attribute.entity 	class entity 	col entity 	type varchar size 64 precision 0 primary key 0
# attribute.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# attribute.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# attribute.type 	class type 	col the_type 	type varchar size 512 precision 0 primary key 0
# attribute.value 	class value 	col the_value 	type varchar size 1024 precision 0 primary key 0
#
# PomSomMapper(id="cartaperdao", table_name="perdoes", class_group="cartaperdao", super_class="act" )
# cartaperdao table perdoes
# cartaperdao.ano 	class year 	col the_year 	type numeric size 4 precision 0 primary key 0
# cartaperdao.cota 	class ref 	col cota 	type varchar size 64 precision 0 primary key 0
# cartaperdao.dia 	class day 	col the_day 	type numeric size 2 precision 0 primary key 0
# cartaperdao.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# cartaperdao.local 	class loc 	col local 	type varchar size 128 precision 0 primary key 0
# cartaperdao.mes 	class month 	col the_month 	type numeric size 2 precision 0 primary key 0
# cartaperdao.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# cartaperdao.tabeliao 	class tabeliao 	col tabeliao 	type varchar size 64 precision 0 primary key 0
# cartaperdao.tipo 	class type 	col the_type 	type varchar size 128 precision 0 primary key 0
#
# PomSomMapper(id="caso", table_name="casos", class_group="caso", super_class="object" )
# caso table casos
# caso.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# caso.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# caso.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# PomSomMapper(id="class", table_name="classes", class_group="na", super_class="entity" )
# class table classes
#
# PomSomMapper(id="crime", table_name="cartas_de_perdao", class_group="crime", super_class="object" )
# crime table cartas_de_perdao
# crime.ano 	class year 	col the_year 	type numeric size 4 precision 0 primary key 0
# crime.descricao 	class descricao 	col descricao 	type varchar size 1024 precision 0 primary key 0
# crime.dia 	class day 	col the_day 	type numeric size 2 precision 0 primary key 0
# crime.forma 	class forma 	col forma 	type varchar size 64 precision 0 primary key 0
# crime.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# crime.instrumento 	class objecto 	col instrumento 	type varchar size 32 precision 0 primary key 0
# crime.local 	class loc 	col local 	type varchar size 32 precision 0 primary key 0
# crime.mes 	class month 	col the_month 	type numeric size 2 precision 0 primary key 0
# crime.objecto 	class objecto 	col objecto 	type varchar size 128 precision 0 primary key 0
# crime.obs 	class obs 	col obs 	type varchar size 1024 precision 0 primary key 0
# crime.ocorrencia 	class ocorrencia 	col ocorrencia 	type varchar size 128 precision 0 primary key 0
# crime.pronuncia 	class pronuncia 	col pronuncia 	type varchar size 128 precision 0 primary key 0
# crime.situacao 	class situacao 	col situacao 	type varchar size 128 precision 0 primary key 0
# crime.subtipo 	class subtipo 	col subtipo 	type varchar size 32 precision 0 primary key 0
# crime.tempo 	class tempo 	col tempo 	type varchar size 32 precision 0 primary key 0
# crime.tipo 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# PomSomMapper(id="divida", table_name="dividas", class_group="divida", super_class="object" )
# divida table dividas
# divida.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# divida.juro 	class juro 	col juro 	type varchar size 32 precision 0 primary key 0
# divida.moeda 	class moeda 	col moeda 	type varchar size 12 precision 0 primary key 0
# divida.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# divida.prazo 	class prazo 	col prazo 	type varchar size 254 precision 0 primary key 0
# divida.valor 	class value 	col the_value 	type varchar size 254 precision 0 primary key 0
# divida.valorn 	class valorn 	col valorn 	type numeric size 12 precision 2 primary key 0
#
# PomSomMapper(id="entity", table_name="entities", class_group="na", super_class="root" )
# entity table entities
# entity.class 	class class 	col class 	type varchar size 64 precision 0 primary key 0
# entity.groupname 	class groupname 	col groupname 	type varchar size 32 precision 0 primary key 0
# entity.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# entity.inside 	class inside 	col inside 	type varchar size 64 precision 0 primary key 0
# entity.level 	class level 	col the_level 	type numeric size 3 precision 0 primary key 0
# entity.line 	class line 	col the_line 	type numeric size 6 precision 0 primary key 0
# entity.order 	class order 	col the_order 	type numeric size 6 precision 0 primary key 0
#
# PomSomMapper(id="escritura", table_name="escrituras", class_group="escritura", super_class="act" )
# escritura table escrituras
# escritura.date 	class date 	col the_date 	type varchar size 24 precision 0 primary key 0
# escritura.fol 	class fol 	col fol 	type varchar size 64 precision 0 primary key 0
# escritura.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# escritura.loc 	class loc 	col loc 	type varchar size 64 precision 0 primary key 0
# escritura.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# escritura.sumario 	class summary 	col summary 	type varchar size 1024 precision 0 primary key 0
# escritura.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# PomSomMapper(id="geoentity", table_name="geoentities", class_group="geoentity", super_class="entity" )
# geoentity table geoentities
# geoentity.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# geoentity.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# geoentity.obs 	class obs 	col obs 	type varchar size 1024 precision 0 primary key 0
# geoentity.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# PomSomMapper(id="good", table_name="goods", class_group="bem", super_class="object" )
# good table goods
# good.description 	class description 	col description 	type varchar size 1024 precision 0 primary key 0
# good.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# good.loc 	class loc 	col loc 	type varchar size 128 precision 0 primary key 0
# good.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# good.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# good.type 	class type 	col the_type 	type varchar size 128 precision 0 primary key 0
#
# PomSomMapper(id="group_element", table_name="gelement", class_group="sacr", super_class="entity" )
# group_element table gelement
# group_element.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# group_element.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# group_element.value 	class value 	col the_value 	type varchar size 254 precision 0 primary key 0
#
# PomSomMapper(id="item", table_name="items", class_group="item", super_class="object" )
# item table items
# item.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# item.resumo 	class resumo 	col resumo 	type varchar size 2048 precision 0 primary key 0
# item.titulo 	class titulo 	col titulo 	type varchar size 128 precision 0 primary key 0
#
# PomSomMapper(id="lgraph", table_name="lgraphs", class_group="lgraph", super_class="entity" )
# lgraph table lgraphs
#
# PomSomMapper(id="object", table_name="objects", class_group="object", super_class="entity" )
# object table objects
# object.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# object.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# object.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# object.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# PomSomMapper(id="person", table_name="persons", class_group="person", super_class="entity" )
# person table persons
# person.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# person.name 	class name 	col name 	type varchar size 128 precision 0 primary key 0
# person.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# person.sex 	class sex 	col sex 	type char size 1 precision 0 primary key 0
#
# PomSomMapper(id="relation", table_name="relations", class_group="relation", super_class="entity" )
# relation table relations
# relation.date 	class date 	col the_date 	type varchar size 24 precision 0 primary key 0
# relation.destination 	class destination 	col destination 	type varchar size 64 precision 0 primary key 0
# relation.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# relation.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# relation.origin 	class origin 	col origin 	type varchar size 64 precision 0 primary key 0
# relation.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
# relation.value 	class value 	col the_value 	type varchar size 254 precision 0 primary key 0
#
# PomSomMapper(id="rentity", table_name="rentities", class_group="rentity", super_class="entity" )
# rentity table rentities
# rentity.description 	class name 	col description 	type varchar size 128 precision 0 primary key 0
# rentity.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# rentity.obs 	class obs 	col obs 	type varchar size 1024 precision 0 primary key 0
# rentity.status 	class status 	col status 	type varchar size 64 precision 0 primary key 0
# rentity.the_class 	class the_class 	col the_class 	type varchar size 32 precision 0 primary key 0
# rentity.user 	class user 	col user 	type varchar size 64 precision 0 primary key 0
#
# PomSomMapper(id="rgeoentity", table_name="rgeoentities", class_group="rgeoentity", super_class="rentity" )
# rgeoentity table rgeoentities
# rgeoentity.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# rgeoentity.obs 	class obs 	col obs 	type text size 32000 precision 0 primary key 0
# rgeoentity.sname 	class sname 	col sname 	type varchar size 64 precision 0 primary key 0
# rgeoentity.status 	class status 	col status 	type char size 1 precision 0 primary key 0
#
# PomSomMapper(id="robject", table_name="robjects", class_group="robject", super_class="rentity" )
# robject table robjects
# robject.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# robject.obs 	class obs 	col obs 	type varchar size 16000 precision 0 primary key 0
# robject.sname 	class sname 	col sname 	type varchar size 64 precision 0 primary key 0
# robject.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
# robject.user 	class user 	col user 	type varchar size 64 precision 0 primary key 0
#
# PomSomMapper(id="rperson", table_name="rpersons", class_group="rperson", super_class="rentity" )
# rperson table rpersons
# rperson.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# rperson.obs 	class obs 	col obs 	type text size 16000 precision 0 primary key 0
# rperson.sex 	class sex 	col sex 	type char size 1 precision 0 primary key 0
# rperson.sname 	class sname 	col sname 	type varchar size 64 precision 0 primary key 0
# rperson.status 	class status 	col status 	type char size 1 precision 0 primary key 0
#
# PomSomMapper(id="source", table_name="sources", class_group="historical-source", super_class="entity" )
# source table sources
# source.date 	class date 	col the_date 	type varchar size 24 precision 0 primary key 0
# source.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# source.kleiofile 	class kleiofile 	col kleiofile 	type varchar size 512 precision 0 primary key 0
# source.loc 	class loc 	col loc 	type varchar size 64 precision 0 primary key 0
# source.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# source.ref 	class ref 	col ref 	type varchar size 64 precision 0 primary key 0
# source.replace 	class replace 	col replaces 	type varchar size 254 precision 0 primary key 0
# source.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
# source.value 	class value 	col the_value 	type varchar size 254 precision 0 primary key 0

# %%
for pom_class in [pc for pc in pom_classes if pc.id in ['entity',
'attribute','relation','person','object','source','act',
'rperson','robject','rentity','geoentity','rgeoentity','good']]:
    print(f"'{pom_class.id}': [")
    print(repr(pom_class),',')
    for cattr in pom_class.class_attributes:
        print(repr(cattr),',')
    print('],')
# Out:
# 'act': [
# PomSomMapper(id="act", table_name="acts", class_group="historical-act", super_class="entity" ) ,
# PomClassAttributes(the_class="act", name="date", colname="the_date", colclass="the_date", coltype="varchar", colsize="24", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="act", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="act", name="loc", colname="loc", colclass="loc", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="act", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="act", name="ref", colname="ref", colclass="ref", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="act", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# ],
# 'attribute': [
# PomSomMapper(id="attribute", table_name="attributes", class_group="attribute", super_class="entity" ) ,
# PomClassAttributes(the_class="attribute", name="date", colname="the_date", colclass="the_date", coltype="varchar", colsize="24", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="attribute", name="entity", colname="entity", colclass="entity", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="attribute", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="attribute", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="attribute", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="attribute", name="value", colname="the_value", colclass="the_value", coltype="varchar", colsize="254", colprecision="0", pkey="0" ) ,
# ],
# 'entity': [
# PomSomMapper(id="entity", table_name="entities", class_group="na", super_class="root" ) ,
# PomClassAttributes(the_class="entity", name="class", colname="class", colclass="class", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="entity", name="groupname", colname="groupname", colclass="groupname", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="entity", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="entity", name="inside", colname="inside", colclass="inside", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="entity", name="level", colname="the_level", colclass="the_level", coltype="numeric", colsize="3", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="entity", name="line", colname="the_line", colclass="the_line", coltype="numeric", colsize="6", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="entity", name="order", colname="the_order", colclass="the_order", coltype="numeric", colsize="6", colprecision="0", pkey="0" ) ,
# ],
# 'geoentity': [
# PomSomMapper(id="geoentity", table_name="geoentities", class_group="geoentity", super_class="entity" ) ,
# PomClassAttributes(the_class="geoentity", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="geoentity", name="name", colname="name", colclass="name", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="geoentity", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="geoentity", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# ],
# 'good': [
# PomSomMapper(id="good", table_name="goods", class_group="bem", super_class="object" ) ,
# PomClassAttributes(the_class="good", name="description", colname="description", colclass="description", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="good", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="good", name="loc", colname="loc", colclass="loc", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="good", name="name", colname="name", colclass="name", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="good", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="good", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# ],
# 'object': [
# PomSomMapper(id="object", table_name="objects", class_group="object", super_class="entity" ) ,
# PomClassAttributes(the_class="object", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="object", name="name", colname="name", colclass="name", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="object", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="object", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# ],
# 'person': [
# PomSomMapper(id="person", table_name="persons", class_group="person", super_class="entity" ) ,
# PomClassAttributes(the_class="person", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="person", name="name", colname="name", colclass="name", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="person", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="person", name="sex", colname="sex", colclass="sex", coltype="char", colsize="1", colprecision="0", pkey="0" ) ,
# ],
# 'relation': [
# PomSomMapper(id="relation", table_name="relations", class_group="relation", super_class="entity" ) ,
# PomClassAttributes(the_class="relation", name="date", colname="the_date", colclass="the_date", coltype="varchar", colsize="24", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="relation", name="destination", colname="destination", colclass="destination", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="relation", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="relation", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="relation", name="origin", colname="origin", colclass="origin", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="relation", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="relation", name="value", colname="the_value", colclass="the_value", coltype="varchar", colsize="254", colprecision="0", pkey="0" ) ,
# ],
# 'rentity': [
# PomSomMapper(id="rentity", table_name="rentities", class_group="rentity", super_class="entity" ) ,
# PomClassAttributes(the_class="rentity", name="description", colname="description", colclass="description", coltype="varchar", colsize="128", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rentity", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="rentity", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rentity", name="status", colname="status", colclass="status", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rentity", name="the_class", colname="the_class", colclass="the_class", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rentity", name="user", colname="user", colclass="user", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# ],
# 'rgeoentity': [
# PomSomMapper(id="rgeoentity", table_name="rgeoentities", class_group="rgeoentity", super_class="rentity" ) ,
# PomClassAttributes(the_class="rgeoentity", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="rgeoentity", name="obs", colname="obs", colclass="obs", coltype="text", colsize="32000", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rgeoentity", name="sname", colname="sname", colclass="sname", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rgeoentity", name="status", colname="status", colclass="status", coltype="char", colsize="1", colprecision="0", pkey="0" ) ,
# ],
# 'robject': [
# PomSomMapper(id="robject", table_name="robjects", class_group="robject", super_class="rentity" ) ,
# PomClassAttributes(the_class="robject", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="robject", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="16000", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="robject", name="sname", colname="sname", colclass="sname", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="robject", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="robject", name="user", colname="user", colclass="user", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# ],
# 'rperson': [
# PomSomMapper(id="rperson", table_name="rpersons", class_group="rperson", super_class="rentity" ) ,
# PomClassAttributes(the_class="rperson", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="rperson", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rperson", name="seq", colname="seq", colclass="seq", coltype="int", colsize="10", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rperson", name="sex", colname="sex", colclass="sex", coltype="varchar", colsize="1", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rperson", name="sname", colname="sname", colclass="sname", coltype="varchar", colsize="128", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rperson", name="status", colname="status", colclass="status", coltype="varchar", colsize="1", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="rperson", name="user", colname="user", colclass="user", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# ],
# 'source': [
# PomSomMapper(id="source", table_name="sources", class_group="historical-source", super_class="entity" ) ,
# PomClassAttributes(the_class="source", name="date", colname="the_date", colclass="the_date", coltype="varchar", colsize="24", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="source", name="id", colname="id", colclass="id", coltype="varchar", colsize="64", colprecision="0", pkey="1" ) ,
# PomClassAttributes(the_class="source", name="kleiofile", colname="kleiofile", colclass="kleiofile", coltype="varchar", colsize="512", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="source", name="loc", colname="loc", colclass="loc", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="source", name="obs", colname="obs", colclass="obs", coltype="varchar", colsize="1024", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="source", name="ref", colname="ref", colclass="ref", coltype="varchar", colsize="64", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="source", name="replace", colname="replaces", colclass="replaces", coltype="varchar", colsize="254", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="source", name="type", colname="the_type", colclass="the_type", coltype="varchar", colsize="32", colprecision="0", pkey="0" ) ,
# PomClassAttributes(the_class="source", name="value", colname="the_value", colclass="the_value", coltype="varchar", colsize="254", colprecision="0", pkey="0" ) ,
# ],

# %% [markdown]
# ## Examining tables

# %%
metadata_obj = Base.metadata
for tname in metadata_obj.tables.keys():
    print(tname)
    for col in metadata_obj.tables[tname].columns:
        print("    ",col.name,col.type)
# Out:
# entities
#      id VARCHAR
#      class VARCHAR
#      inside VARCHAR
#      the_order INTEGER
#      the_level INTEGER
#      the_line INTEGER
#      groupname VARCHAR
#      updated DATETIME
#      indexed DATETIME
# attributes
#      id VARCHAR
#      entity VARCHAR
#      the_type VARCHAR
#      the_value VARCHAR
#      the_date VARCHAR
#      obs VARCHAR
# relations
#      id VARCHAR
#      origin VARCHAR
#      destination VARCHAR
#      the_type VARCHAR
#      the_value VARCHAR
#      the_date VARCHAR
#      obs VARCHAR
# persons
#      id VARCHAR
#      name VARCHAR
#      sex VARCHAR(1)
#      obs VARCHAR
# objects
#      id VARCHAR
#      name VARCHAR
#      the_type VARCHAR(32)
#      obs VARCHAR
# acts
#      id VARCHAR
#      the_type VARCHAR(32)
#      the_date VARCHAR
#      loc VARCHAR
#      ref VARCHAR
#      obs VARCHAR
# sources
#      id VARCHAR
#      the_type VARCHAR(32)
#      the_date VARCHAR
#      loc VARCHAR
#      ref VARCHAR
#      kleiofile VARCHAR
#      replaces VARCHAR
#      obs VARCHAR
# classes
#      id VARCHAR
#      table_name VARCHAR
#      group_name VARCHAR(32)
#      super VARCHAR
# class_attributes
#      the_class VARCHAR
#      name VARCHAR(32)
#      colname VARCHAR(32)
#      colclass VARCHAR(32)
#      coltype VARCHAR
#      colsize INTEGER
#      colprecision INTEGER
#      pkey INTEGER

# %% [markdown]
# ## Dynamic mappings for user defined SomPom classes

# %%
from sqlalchemy import Table, Column,Integer, String, Float
pytables = metadata_obj.tables
pom_classes = session.query(PomSomMapper).where(Entity.pom_class  == 'class').all()
pom_class: PomSomMapper
for pom_class in pom_classes:
    if pom_class.table_name in pytables.keys():
        print(pom_class.id,"maps to ")
        print("    ",repr(pytables[pom_class.table_name]))
    else:
        print()
        print(pom_class.id, "python table missing. Creating new")
        print("PomSom information")
        print(pom_class)

        NewTable: Table = Table(pom_class.table_name,metadata_obj,extend_existing=True)

        cattr: PomClassAttributes
        for cattr in pom_class.class_attributes:
            PyType = None
            pom_type = cattr.coltype.lower()
            if pom_type == 'varchar':
                PyType = String(cattr.colsize)
            elif pom_type == 'numeric' and cattr.colprecision == 0 :
                PyType = Integer
            elif pom_type == 'numeric' and cattr.colprecision > 0:
                PyType = Float
            else:
                PyType = String
            print(f"Inferred python type for {cattr.colname}: ",PyType)

            print("Getting super class "+pom_class.super_class)
            PomSuperClass: PomSomMapper = PomSomMapper.get_pom_class(session, pom_class.super_class)
            if PomSuperClass is not None:
                super_class_table_id = PomSuperClass.table_name+'.id'
            else:
                print("ERROR coould not find superclass: ",pom_class.super_class)
                super_class_table_id = 'entities.id'
            if cattr.pkey != 0:
                NewTable.append_column(Column(cattr.colname,PyType,ForeignKey(super_class_table_id), primary_key=True),replace_existing=True)
            else:
                NewTable.append_column(Column(cattr.colname,PyType,primary_key=False),replace_existing=True)
        
        print("----")
        print(repr(NewTable))
        pom_class.__table__= NewTable
# Out:
# act maps to
#      Table('acts', MetaData(), Column('id', String(), ForeignKey('entities.id'), table=<acts>, primary_key=True, nullable=False), Column('the_type', String(length=32), table=<acts>), Column('the_date', String(), table=<acts>), Column('loc', String(), table=<acts>), Column('ref', String(), table=<acts>), Column('obs', String(), table=<acts>), schema=None)
#
# acta python table missing. Creating new
# PomSom information
# acta table actas super act
# acta.ano 	class year 	col the_year 	type numeric size 4 precision 0 primary key 0
# acta.dia 	class day 	col the_day 	type numeric size 2 precision 0 primary key 0
# acta.fol 	class fol 	col fol 	type varchar size 64 precision 0 primary key 0
# acta.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# acta.mes 	class month 	col the_month 	type numeric size 2 precision 0 primary key 0
# acta.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# acta.resumo 	class resumo 	col resumo 	type varchar size 1024 precision 0 primary key 0
#
# Inferred python type for the_year:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class act
# Inferred python type for the_day:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class act
# Inferred python type for fol:  VARCHAR(64)
# Getting super class act
# Inferred python type for id:  VARCHAR(64)
# Getting super class act
# Inferred python type for the_month:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class act
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class act
# Inferred python type for resumo:  VARCHAR(1024)
# Getting super class act
# ----
# Table('actas', MetaData(), Column('the_year', Integer(), table=<actas>), Column('the_day', Integer(), table=<actas>), Column('fol', String(length=Decimal('64')), table=<actas>), Column('id', String(length=Decimal('64')), ForeignKey('acts.id'), table=<actas>, primary_key=True, nullable=False), Column('the_month', Integer(), table=<actas>), Column('obs', String(length=Decimal('16654')), table=<actas>), Column('resumo', String(length=Decimal('1024')), table=<actas>), schema=None)
#
# acusacoes python table missing. Creating new
# PomSom information
# acusacoes table acusacoes super object
# acusacoes.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# acusacoes.idcaso 	class idcaso 	col idcaso 	type varchar size 64 precision 0 primary key 0
# acusacoes.literal 	class literal 	col literal 	type varchar size 16000 precision 0 primary key 0
# acusacoes.obs 	class obs 	col obs 	type varchar size 16000 precision 0 primary key 0
# acusacoes.origem 	class origem 	col origem 	type varchar size 16000 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class object
# Inferred python type for idcaso:  VARCHAR(64)
# Getting super class object
# Inferred python type for literal:  VARCHAR(16000)
# Getting super class object
# Inferred python type for obs:  VARCHAR(16000)
# Getting super class object
# Inferred python type for origem:  VARCHAR(16000)
# Getting super class object
# ----
# Table('acusacoes', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('objects.id'), table=<acusacoes>, primary_key=True, nullable=False), Column('idcaso', String(length=Decimal('64')), table=<acusacoes>), Column('literal', String(length=Decimal('16000')), table=<acusacoes>), Column('obs', String(length=Decimal('16000')), table=<acusacoes>), Column('origem', String(length=Decimal('16000')), table=<acusacoes>), schema=None)
#
# aforamento python table missing. Creating new
# PomSom information
# aforamento table aforamentos super good
# aforamento.description 	class description 	col description 	type varchar size 1024 precision 0 primary key 0
# aforamento.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# aforamento.loc 	class loc 	col loc 	type varchar size 64 precision 0 primary key 0
# aforamento.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# aforamento.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# aforamento.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# Inferred python type for description:  VARCHAR(1024)
# Getting super class good
# Inferred python type for id:  VARCHAR(64)
# Getting super class good
# Inferred python type for loc:  VARCHAR(64)
# Getting super class good
# Inferred python type for name:  VARCHAR(64)
# Getting super class good
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class good
# Inferred python type for the_type:  VARCHAR(32)
# Getting super class good
# ----
# Table('aforamentos', MetaData(), Column('description', String(length=Decimal('1024')), table=<aforamentos>), Column('id', String(length=Decimal('64')), ForeignKey('goods.id'), table=<aforamentos>, primary_key=True, nullable=False), Column('loc', String(length=Decimal('64')), table=<aforamentos>), Column('name', String(length=Decimal('64')), table=<aforamentos>), Column('obs', String(length=Decimal('16654')), table=<aforamentos>), Column('the_type', String(length=Decimal('32')), table=<aforamentos>), schema=None)
#
# aregister python table missing. Creating new
# PomSom information
# aregister table aregisters super entity
# aregister.date 	class date 	col the_date 	type varchar size 24 precision 0 primary key 0
# aregister.dbase 	class dbase 	col dbase 	type varchar size 32 precision 0 primary key 0
# aregister.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# aregister.ignore_date 	class ignore_date 	col ignore_date 	type varchar size 64 precision 0 primary key 0
# aregister.mode 	class mode 	col mode 	type varchar size 64 precision 0 primary key 0
# aregister.name 	class name 	col name 	type varchar size 254 precision 0 primary key 0
# aregister.obs 	class obs 	col obs 	type varchar size 1024 precision 0 primary key 0
# aregister.replace_mode 	class replace_mode 	col replace_mode 	type varchar size 64 precision 0 primary key 0
# aregister.user 	class user 	col user 	type varchar size 32 precision 0 primary key 0
#
# Inferred python type for the_date:  VARCHAR(24)
# Getting super class entity
# Inferred python type for dbase:  VARCHAR(32)
# Getting super class entity
# Inferred python type for id:  VARCHAR(64)
# Getting super class entity
# Inferred python type for ignore_date:  VARCHAR(64)
# Getting super class entity
# Inferred python type for mode:  VARCHAR(64)
# Getting super class entity
# Inferred python type for name:  VARCHAR(254)
# Getting super class entity
# Inferred python type for obs:  VARCHAR(1024)
# Getting super class entity
# Inferred python type for replace_mode:  VARCHAR(64)
# Getting super class entity
# Inferred python type for user:  VARCHAR(32)
# Getting super class entity
# ----
# Table('aregisters', MetaData(), Column('the_date', String(length=Decimal('24')), table=<aregisters>), Column('dbase', String(length=Decimal('32')), table=<aregisters>), Column('id', String(length=Decimal('64')), ForeignKey('entities.id'), table=<aregisters>, primary_key=True, nullable=False), Column('ignore_date', String(length=Decimal('64')), table=<aregisters>), Column('mode', String(length=Decimal('64')), table=<aregisters>), Column('name', String(length=Decimal('254')), table=<aregisters>), Column('obs', String(length=Decimal('1024')), table=<aregisters>), Column('replace_mode', String(length=Decimal('64')), table=<aregisters>), Column('user', String(length=Decimal('32')), table=<aregisters>), schema=None)
# attribute maps to
#      Table('attributes', MetaData(), Column('id', String(), ForeignKey('entities.id'), table=<attributes>, primary_key=True, nullable=False), Column('entity', String(), ForeignKey('entities.id'), table=<attributes>), Column('the_type', String(), table=<attributes>), Column('the_value', String(), table=<attributes>), Column('the_date', String(), table=<attributes>), Column('obs', String(), table=<attributes>), schema=None)
#
# cartaperdao python table missing. Creating new
# PomSom information
# cartaperdao table perdoes super act
# cartaperdao.ano 	class year 	col the_year 	type numeric size 4 precision 0 primary key 0
# cartaperdao.cota 	class ref 	col cota 	type varchar size 64 precision 0 primary key 0
# cartaperdao.dia 	class day 	col the_day 	type numeric size 2 precision 0 primary key 0
# cartaperdao.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# cartaperdao.local 	class loc 	col local 	type varchar size 128 precision 0 primary key 0
# cartaperdao.mes 	class month 	col the_month 	type numeric size 2 precision 0 primary key 0
# cartaperdao.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# cartaperdao.tabeliao 	class tabeliao 	col tabeliao 	type varchar size 64 precision 0 primary key 0
# cartaperdao.tipo 	class type 	col the_type 	type varchar size 128 precision 0 primary key 0
#
# Inferred python type for the_year:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class act
# Inferred python type for cota:  VARCHAR(64)
# Getting super class act
# Inferred python type for the_day:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class act
# Inferred python type for id:  VARCHAR(64)
# Getting super class act
# Inferred python type for local:  VARCHAR(128)
# Getting super class act
# Inferred python type for the_month:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class act
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class act
# Inferred python type for tabeliao:  VARCHAR(64)
# Getting super class act
# Inferred python type for the_type:  VARCHAR(128)
# Getting super class act
# ----
# Table('perdoes', MetaData(), Column('the_year', Integer(), table=<perdoes>), Column('cota', String(length=Decimal('64')), table=<perdoes>), Column('the_day', Integer(), table=<perdoes>), Column('id', String(length=Decimal('64')), ForeignKey('acts.id'), table=<perdoes>, primary_key=True, nullable=False), Column('local', String(length=Decimal('128')), table=<perdoes>), Column('the_month', Integer(), table=<perdoes>), Column('obs', String(length=Decimal('16654')), table=<perdoes>), Column('tabeliao', String(length=Decimal('64')), table=<perdoes>), Column('the_type', String(length=Decimal('128')), table=<perdoes>), schema=None)
#
# caso python table missing. Creating new
# PomSom information
# caso table casos super object
# caso.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# caso.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# caso.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class object
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class object
# Inferred python type for the_type:  VARCHAR(32)
# Getting super class object
# ----
# Table('casos', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('objects.id'), table=<casos>, primary_key=True, nullable=False), Column('obs', String(length=Decimal('16654')), table=<casos>), Column('the_type', String(length=Decimal('32')), table=<casos>), schema=None)
# class maps to
#      Table('classes', MetaData(), Column('id', String(), ForeignKey('entities.id'), table=<classes>, primary_key=True, nullable=False), Column('table_name', String(), table=<classes>), Column('group_name', String(length=32), table=<classes>), Column('super', String(), table=<classes>), schema=None)
#
# crime python table missing. Creating new
# PomSom information
# crime table cartas_de_perdao super object
# crime.ano 	class year 	col the_year 	type numeric size 4 precision 0 primary key 0
# crime.descricao 	class descricao 	col descricao 	type varchar size 1024 precision 0 primary key 0
# crime.dia 	class day 	col the_day 	type numeric size 2 precision 0 primary key 0
# crime.forma 	class forma 	col forma 	type varchar size 64 precision 0 primary key 0
# crime.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# crime.instrumento 	class objecto 	col instrumento 	type varchar size 32 precision 0 primary key 0
# crime.local 	class loc 	col local 	type varchar size 32 precision 0 primary key 0
# crime.mes 	class month 	col the_month 	type numeric size 2 precision 0 primary key 0
# crime.objecto 	class objecto 	col objecto 	type varchar size 128 precision 0 primary key 0
# crime.obs 	class obs 	col obs 	type varchar size 1024 precision 0 primary key 0
# crime.ocorrencia 	class ocorrencia 	col ocorrencia 	type varchar size 128 precision 0 primary key 0
# crime.pronuncia 	class pronuncia 	col pronuncia 	type varchar size 128 precision 0 primary key 0
# crime.situacao 	class situacao 	col situacao 	type varchar size 128 precision 0 primary key 0
# crime.subtipo 	class subtipo 	col subtipo 	type varchar size 32 precision 0 primary key 0
# crime.tempo 	class tempo 	col tempo 	type varchar size 32 precision 0 primary key 0
# crime.tipo 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# Inferred python type for the_year:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class object
# Inferred python type for descricao:  VARCHAR(1024)
# Getting super class object
# Inferred python type for the_day:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class object
# Inferred python type for forma:  VARCHAR(64)
# Getting super class object
# Inferred python type for id:  VARCHAR(64)
# Getting super class object
# Inferred python type for instrumento:  VARCHAR(32)
# Getting super class object
# Inferred python type for local:  VARCHAR(32)
# Getting super class object
# Inferred python type for the_month:  <class 'sqlalchemy.sql.sqltypes.Integer'>
# Getting super class object
# Inferred python type for objecto:  VARCHAR(128)
# Getting super class object
# Inferred python type for obs:  VARCHAR(1024)
# Getting super class object
# Inferred python type for ocorrencia:  VARCHAR(128)
# Getting super class object
# Inferred python type for pronuncia:  VARCHAR(128)
# Getting super class object
# Inferred python type for situacao:  VARCHAR(128)
# Getting super class object
# Inferred python type for subtipo:  VARCHAR(32)
# Getting super class object
# Inferred python type for tempo:  VARCHAR(32)
# Getting super class object
# Inferred python type for the_type:  VARCHAR(32)
# Getting super class object
# ----
# Table('cartas_de_perdao', MetaData(), Column('the_year', Integer(), table=<cartas_de_perdao>), Column('descricao', String(length=Decimal('1024')), table=<cartas_de_perdao>), Column('the_day', Integer(), table=<cartas_de_perdao>), Column('forma', String(length=Decimal('64')), table=<cartas_de_perdao>), Column('id', String(length=Decimal('64')), ForeignKey('objects.id'), table=<cartas_de_perdao>, primary_key=True, nullable=False), Column('instrumento', String(length=Decimal('32')), table=<cartas_de_perdao>), Column('local', String(length=Decimal('32')), table=<cartas_de_perdao>), Column('the_month', Integer(), table=<cartas_de_perdao>), Column('objecto', String(length=Decimal('128')), table=<cartas_de_perdao>), Column('obs', String(length=Decimal('1024')), table=<cartas_de_perdao>), Column('ocorrencia', String(length=Decimal('128')), table=<cartas_de_perdao>), Column('pronuncia', String(length=Decimal('128')), table=<cartas_de_perdao>), Column('situacao', String(length=Decimal('128')), table=<cartas_de_perdao>), Column('subtipo', String(length=Decimal('32')), table=<cartas_de_perdao>), Column('tempo', String(length=Decimal('32')), table=<cartas_de_perdao>), Column('the_type', String(length=Decimal('32')), table=<cartas_de_perdao>), schema=None)
#
# divida python table missing. Creating new
# PomSom information
# divida table dividas super object
# divida.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# divida.juro 	class juro 	col juro 	type varchar size 32 precision 0 primary key 0
# divida.moeda 	class moeda 	col moeda 	type varchar size 12 precision 0 primary key 0
# divida.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# divida.prazo 	class prazo 	col prazo 	type varchar size 254 precision 0 primary key 0
# divida.valor 	class value 	col the_value 	type varchar size 254 precision 0 primary key 0
# divida.valorn 	class valorn 	col valorn 	type numeric size 12 precision 2 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class object
# Inferred python type for juro:  VARCHAR(32)
# Getting super class object
# Inferred python type for moeda:  VARCHAR(12)
# Getting super class object
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class object
# Inferred python type for prazo:  VARCHAR(254)
# Getting super class object
# Inferred python type for the_value:  VARCHAR(254)
# Getting super class object
# Inferred python type for valorn:  <class 'sqlalchemy.sql.sqltypes.Float'>
# Getting super class object
# ----
# Table('dividas', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('objects.id'), table=<dividas>, primary_key=True, nullable=False), Column('juro', String(length=Decimal('32')), table=<dividas>), Column('moeda', String(length=Decimal('12')), table=<dividas>), Column('obs', String(length=Decimal('16654')), table=<dividas>), Column('prazo', String(length=Decimal('254')), table=<dividas>), Column('the_value', String(length=Decimal('254')), table=<dividas>), Column('valorn', Float(), table=<dividas>), schema=None)
# entity maps to
#      Table('entities', MetaData(), Column('id', String(), table=<entities>, primary_key=True, nullable=False), Column('class', String(), ForeignKey('classes.id'), table=<entities>), Column('inside', String(), ForeignKey('entities.id'), table=<entities>), Column('the_order', Integer(), table=<entities>), Column('the_level', Integer(), table=<entities>), Column('the_line', Integer(), table=<entities>), Column('groupname', String(), table=<entities>), Column('updated', DateTime(), table=<entities>), Column('indexed', DateTime(), table=<entities>), schema=None)
#
# escritura python table missing. Creating new
# PomSom information
# escritura table escrituras super act
# escritura.date 	class date 	col the_date 	type varchar size 24 precision 0 primary key 0
# escritura.fol 	class fol 	col fol 	type varchar size 64 precision 0 primary key 0
# escritura.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# escritura.loc 	class loc 	col loc 	type varchar size 64 precision 0 primary key 0
# escritura.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# escritura.sumario 	class summary 	col summary 	type varchar size 1024 precision 0 primary key 0
# escritura.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# Inferred python type for the_date:  VARCHAR(24)
# Getting super class act
# Inferred python type for fol:  VARCHAR(64)
# Getting super class act
# Inferred python type for id:  VARCHAR(64)
# Getting super class act
# Inferred python type for loc:  VARCHAR(64)
# Getting super class act
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class act
# Inferred python type for summary:  VARCHAR(1024)
# Getting super class act
# Inferred python type for the_type:  VARCHAR(32)
# Getting super class act
# ----
# Table('escrituras', MetaData(), Column('the_date', String(length=Decimal('24')), table=<escrituras>), Column('fol', String(length=Decimal('64')), table=<escrituras>), Column('id', String(length=Decimal('64')), ForeignKey('acts.id'), table=<escrituras>, primary_key=True, nullable=False), Column('loc', String(length=Decimal('64')), table=<escrituras>), Column('obs', String(length=Decimal('16654')), table=<escrituras>), Column('summary', String(length=Decimal('1024')), table=<escrituras>), Column('the_type', String(length=Decimal('32')), table=<escrituras>), schema=None)
#
# geoentity python table missing. Creating new
# PomSom information
# geoentity table geoentities super entity
# geoentity.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# geoentity.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# geoentity.obs 	class obs 	col obs 	type varchar size 1024 precision 0 primary key 0
# geoentity.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class entity
# Inferred python type for name:  VARCHAR(64)
# Getting super class entity
# Inferred python type for obs:  VARCHAR(1024)
# Getting super class entity
# Inferred python type for the_type:  VARCHAR(32)
# Getting super class entity
# ----
# Table('geoentities', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('entities.id'), table=<geoentities>, primary_key=True, nullable=False), Column('name', String(length=Decimal('64')), table=<geoentities>), Column('obs', String(length=Decimal('1024')), table=<geoentities>), Column('the_type', String(length=Decimal('32')), table=<geoentities>), schema=None)
#
# good python table missing. Creating new
# PomSom information
# good table goods super object
# good.description 	class description 	col description 	type varchar size 1024 precision 0 primary key 0
# good.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# good.loc 	class loc 	col loc 	type varchar size 128 precision 0 primary key 0
# good.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# good.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# good.type 	class type 	col the_type 	type varchar size 128 precision 0 primary key 0
#
# Inferred python type for description:  VARCHAR(1024)
# Getting super class object
# Inferred python type for id:  VARCHAR(64)
# Getting super class object
# Inferred python type for loc:  VARCHAR(128)
# Getting super class object
# Inferred python type for name:  VARCHAR(64)
# Getting super class object
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class object
# Inferred python type for the_type:  VARCHAR(128)
# Getting super class object
# ----
# Table('goods', MetaData(), Column('description', String(length=Decimal('1024')), table=<goods>), Column('id', String(length=Decimal('64')), ForeignKey('objects.id'), table=<goods>, primary_key=True, nullable=False), Column('loc', String(length=Decimal('128')), table=<goods>), Column('name', String(length=Decimal('64')), table=<goods>), Column('obs', String(length=Decimal('16654')), table=<goods>), Column('the_type', String(length=Decimal('128')), table=<goods>), schema=None)
#
# group_element python table missing. Creating new
# PomSom information
# group_element table gelement super entity
# group_element.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# group_element.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# group_element.value 	class value 	col the_value 	type varchar size 254 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class entity
# Inferred python type for obs:  VARCHAR(16654)
# Getting super class entity
# Inferred python type for the_value:  VARCHAR(254)
# Getting super class entity
# ----
# Table('gelement', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('entities.id'), table=<gelement>, primary_key=True, nullable=False), Column('obs', String(length=Decimal('16654')), table=<gelement>), Column('the_value', String(length=Decimal('254')), table=<gelement>), schema=None)
#
# item python table missing. Creating new
# PomSom information
# item table items super object
# item.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# item.resumo 	class resumo 	col resumo 	type varchar size 2048 precision 0 primary key 0
# item.titulo 	class titulo 	col titulo 	type varchar size 128 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class object
# Inferred python type for resumo:  VARCHAR(2048)
# Getting super class object
# Inferred python type for titulo:  VARCHAR(128)
# Getting super class object
# ----
# Table('items', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('objects.id'), table=<items>, primary_key=True, nullable=False), Column('resumo', String(length=Decimal('2048')), table=<items>), Column('titulo', String(length=Decimal('128')), table=<items>), schema=None)
#
# lgraph python table missing. Creating new
# PomSom information
# lgraph table lgraphs super entity
#
# ----
# Table('lgraphs', MetaData(), schema=None)
# object maps to
#      Table('objects', MetaData(), Column('id', String(), ForeignKey('entities.id'), table=<objects>, primary_key=True, nullable=False), Column('name', String(), table=<objects>), Column('the_type', String(length=32), table=<objects>), Column('obs', String(), table=<objects>), schema=None)
# person maps to
#      Table('persons', MetaData(), Column('id', String(), ForeignKey('entities.id'), table=<persons>, primary_key=True, nullable=False), Column('name', String(), table=<persons>), Column('sex', String(length=1), table=<persons>), Column('obs', String(), table=<persons>), schema=None)
# relation maps to
#      Table('relations', MetaData(), Column('id', String(), ForeignKey('entities.id'), table=<relations>, primary_key=True, nullable=False), Column('origin', String(), ForeignKey('entities.id'), table=<relations>), Column('destination', String(), ForeignKey('entities.id'), table=<relations>), Column('the_type', String(), table=<relations>), Column('the_value', String(), table=<relations>), Column('the_date', String(), table=<relations>), Column('obs', String(), table=<relations>), schema=None)
#
# rgeoentity python table missing. Creating new
# PomSom information
# rgeoentity table rgeoentities super rentity
# rgeoentity.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# rgeoentity.obs 	class obs 	col obs 	type text size 32000 precision 0 primary key 0
# rgeoentity.sname 	class sname 	col sname 	type varchar size 64 precision 0 primary key 0
# rgeoentity.status 	class status 	col status 	type char size 1 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for obs:  <class 'sqlalchemy.sql.sqltypes.String'>
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for sname:  VARCHAR(64)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for status:  <class 'sqlalchemy.sql.sqltypes.String'>
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# ----
# Table('rgeoentities', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('entities.id'), table=<rgeoentities>, primary_key=True, nullable=False), Column('obs', String(), table=<rgeoentities>), Column('sname', String(length=Decimal('64')), table=<rgeoentities>), Column('status', String(), table=<rgeoentities>), schema=None)
#
# robject python table missing. Creating new
# PomSom information
# robject table robjects super rentity
# robject.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# robject.obs 	class obs 	col obs 	type varchar size 16000 precision 0 primary key 0
# robject.sname 	class sname 	col sname 	type varchar size 64 precision 0 primary key 0
# robject.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
# robject.user 	class user 	col user 	type varchar size 64 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for obs:  VARCHAR(16000)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for sname:  VARCHAR(64)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for the_type:  VARCHAR(32)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for user:  VARCHAR(64)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# ----
# Table('robjects', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('entities.id'), table=<robjects>, primary_key=True, nullable=False), Column('obs', String(length=Decimal('16000')), table=<robjects>), Column('sname', String(length=Decimal('64')), table=<robjects>), Column('the_type', String(length=Decimal('32')), table=<robjects>), Column('user', String(length=Decimal('64')), table=<robjects>), schema=None)
#
# rperson python table missing. Creating new
# PomSom information
# rperson table rpersons super rentity
# rperson.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# rperson.obs 	class obs 	col obs 	type text size 16000 precision 0 primary key 0
# rperson.sex 	class sex 	col sex 	type char size 1 precision 0 primary key 0
# rperson.sname 	class sname 	col sname 	type varchar size 64 precision 0 primary key 0
# rperson.status 	class status 	col status 	type char size 1 precision 0 primary key 0
#
# Inferred python type for id:  VARCHAR(64)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for obs:  <class 'sqlalchemy.sql.sqltypes.String'>
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for sex:  <class 'sqlalchemy.sql.sqltypes.String'>
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for sname:  VARCHAR(64)
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# Inferred python type for status:  <class 'sqlalchemy.sql.sqltypes.String'>
# Getting super class rentity
# ERROR coould not find superclass:  rentity
# ----
# Table('rpersons', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('entities.id'), table=<rpersons>, primary_key=True, nullable=False), Column('obs', String(), table=<rpersons>), Column('sex', String(), table=<rpersons>), Column('sname', String(length=Decimal('64')), table=<rpersons>), Column('status', String(), table=<rpersons>), schema=None)
# source maps to
#      Table('sources', MetaData(), Column('id', String(), ForeignKey('entities.id'), table=<sources>, primary_key=True, nullable=False), Column('the_type', String(length=32), table=<sources>), Column('the_date', String(), table=<sources>), Column('loc', String(), table=<sources>), Column('ref', String(), table=<sources>), Column('kleiofile', String(), table=<sources>), Column('replaces', String(), table=<sources>), Column('obs', String(), table=<sources>), schema=None)

# %% [markdown]
# ### Metadata with new dynamic tables

# %%
newtables = metadata_obj.tables
for name, table in newtables.items():
    print(name)
    for col in table.columns:
        print("    ",col.name,col.type)
# Out:
# entities
#      id VARCHAR
#      class VARCHAR
#      inside VARCHAR
#      the_order INTEGER
#      the_level INTEGER
#      the_line INTEGER
#      groupname VARCHAR
#      updated DATETIME
#      indexed DATETIME
# attributes
#      id VARCHAR
#      entity VARCHAR
#      the_type VARCHAR
#      the_value VARCHAR
#      the_date VARCHAR
#      obs VARCHAR
# relations
#      id VARCHAR
#      origin VARCHAR
#      destination VARCHAR
#      the_type VARCHAR
#      the_value VARCHAR
#      the_date VARCHAR
#      obs VARCHAR
# persons
#      id VARCHAR
#      name VARCHAR
#      sex VARCHAR(1)
#      obs VARCHAR
# objects
#      id VARCHAR
#      name VARCHAR
#      the_type VARCHAR(32)
#      obs VARCHAR
# acts
#      id VARCHAR
#      the_type VARCHAR(32)
#      the_date VARCHAR
#      loc VARCHAR
#      ref VARCHAR
#      obs VARCHAR
# sources
#      id VARCHAR
#      the_type VARCHAR(32)
#      the_date VARCHAR
#      loc VARCHAR
#      ref VARCHAR
#      kleiofile VARCHAR
#      replaces VARCHAR
#      obs VARCHAR
# classes
#      id VARCHAR
#      table_name VARCHAR
#      group_name VARCHAR(32)
#      super VARCHAR
# class_attributes
#      the_class VARCHAR
#      name VARCHAR(32)
#      colname VARCHAR(32)
#      colclass VARCHAR(32)
#      coltype VARCHAR
#      colsize INTEGER
#      colprecision INTEGER
#      pkey INTEGER
# actas
#      the_year INTEGER
#      the_day INTEGER
#      fol VARCHAR(64)
#      id VARCHAR(64)
#      the_month INTEGER
#      obs VARCHAR(16654)
#      resumo VARCHAR(1024)
# acusacoes
#      id VARCHAR(64)
#      idcaso VARCHAR(64)
#      literal VARCHAR(16000)
#      obs VARCHAR(16000)
#      origem VARCHAR(16000)
# aforamentos
#      description VARCHAR(1024)
#      id VARCHAR(64)
#      loc VARCHAR(64)
#      name VARCHAR(64)
#      obs VARCHAR(16654)
#      the_type VARCHAR(32)
# aregisters
#      the_date VARCHAR(24)
#      dbase VARCHAR(32)
#      id VARCHAR(64)
#      ignore_date VARCHAR(64)
#      mode VARCHAR(64)
#      name VARCHAR(254)
#      obs VARCHAR(1024)
#      replace_mode VARCHAR(64)
#      user VARCHAR(32)
# perdoes
#      the_year INTEGER
#      cota VARCHAR(64)
#      the_day INTEGER
#      id VARCHAR(64)
#      local VARCHAR(128)
#      the_month INTEGER
#      obs VARCHAR(16654)
#      tabeliao VARCHAR(64)
#      the_type VARCHAR(128)
# casos
#      id VARCHAR(64)
#      obs VARCHAR(16654)
#      the_type VARCHAR(32)
# cartas_de_perdao
#      the_year INTEGER
#      descricao VARCHAR(1024)
#      the_day INTEGER
#      forma VARCHAR(64)
#      id VARCHAR(64)
#      instrumento VARCHAR(32)
#      local VARCHAR(32)
#      the_month INTEGER
#      objecto VARCHAR(128)
#      obs VARCHAR(1024)
#      ocorrencia VARCHAR(128)
#      pronuncia VARCHAR(128)
#      situacao VARCHAR(128)
#      subtipo VARCHAR(32)
#      tempo VARCHAR(32)
#      the_type VARCHAR(32)
# dividas
#      id VARCHAR(64)
#      juro VARCHAR(32)
#      moeda VARCHAR(12)
#      obs VARCHAR(16654)
#      prazo VARCHAR(254)
#      the_value VARCHAR(254)
#      valorn FLOAT
# escrituras
#      the_date VARCHAR(24)
#      fol VARCHAR(64)
#      id VARCHAR(64)
#      loc VARCHAR(64)
#      obs VARCHAR(16654)
#      summary VARCHAR(1024)
#      the_type VARCHAR(32)
# geoentities
#      id VARCHAR(64)
#      name VARCHAR(64)
#      obs VARCHAR(1024)
#      the_type VARCHAR(32)
# goods
#      description VARCHAR(1024)
#      id VARCHAR(64)
#      loc VARCHAR(128)
#      name VARCHAR(64)
#      obs VARCHAR(16654)
#      the_type VARCHAR(128)
# gelement
#      id VARCHAR(64)
#      obs VARCHAR(16654)
#      the_value VARCHAR(254)
# items
#      id VARCHAR(64)
#      resumo VARCHAR(2048)
#      titulo VARCHAR(128)
# lgraphs
# rgeoentities
#      id VARCHAR(64)
#      obs VARCHAR
#      sname VARCHAR(64)
#      status VARCHAR
# robjects
#      id VARCHAR(64)
#      obs VARCHAR(16000)
#      sname VARCHAR(64)
#      the_type VARCHAR(32)
#      user VARCHAR(64)
# rpersons
#      id VARCHAR(64)
#      obs VARCHAR
#      sex VARCHAR
#      sname VARCHAR(64)
#      status VARCHAR

# %% [markdown]
# ## Creating new Mapped Classes for the inferred tables
#
#         from sqlalchemy.orm import registry
#
#         mapper_registry = registry()
#
#         my_table = Table(
#             "my_table",
#             mapper_registry.metadata,
#             Column('id', Integer, primary_key=True)
#         )
#
#         class MyClass:
#             pass
#
#         mapper_registry.map_imperatively(MyClass, my_table)
#
#
# https://docs.sqlalchemy.org/en/14/orm/mapping_api.html

# %%
casos_table = metadata_obj.tables['casos']
print(casos_table.name)
for col in casos_table.columns:
    print("    ",col.name,col.type)
s = select(casos_table)
print(s)
results = session.execute(s)
for c in results:
    print(c)
# Out:
# casos
#      id VARCHAR(64)
#      obs VARCHAR(16654)
#      the_type VARCHAR(32)
# SELECT casos.id, casos.obs, casos.the_type
# FROM casos
# ('1708-c1', 'na pronuncia sao setenciados a fazerem vida marital e ele a a tratar bem. pronuncia: admoestacao,resultado: fez termo', 'violf')
# ('1708-c2', None, 'nfvida')
# ('1708-c3', None, 'amanc')
# ('1708-c4', None, 'amanc')
# ('1708-c5', None, 'cons')
# ('1708-c6', None, 'ma lin')
# ('1708-c7', None, 'violf')
# ('1708-c8', None, 'ma lin')
# ('1708-c9', " ela casou-se em 21 de Fevereiro de 1707, ha' um ano e meio", 'amanc')
# ('c1690-luisa-manrique-maria-simoes', '"""\n                   \n                  Ela vive longe do marido, numa casa por conta dele. \n                  Já acusados em visitas anteriores44relacao com muitos anos.\n\n                  """', 'amanc')
# ('c1692-ana-simoes-feiticeira', 'ana simoes,2114a', 'feitic')
# ('c1692-antonio-catarina-fernandes', 'tiveram filho(a). 2.o a t.a 23 manuel goncalves, ele foi prezo por ordem do pai dela.', 'amanc')
# ('c1692-antonio-cordeiro-alcouc', 'dava mulheres em casa. Margem: tirada de ambos 1.1.1691%1o. 8.bro 691. ', 'alcouc')
# ('c1692-antonio-gomes-maria', 'quarto grau margem: tirada dela em 25.1.692 dele 14.5.1693', 'amanci')
# ('c1692-antonio-simoes-maria-domingues', 'da filha', 'cons')
# ('c1692-antonio-simoes-raposo-maria', None, 'amanc')
# ('c1692-baptista-moura-domingas-carvalho', 'baptista de moura e isabel, 2140 e 2141 2.o grau de afinidade', 'amanci')
# ('c1692-catarina-gaspar-curas', 'benze e cura de quebranto', 'curas')
# ('c1692-domingo-antunes-nfvida', None, 'nfvida')
# ('c1692-joao-rodrigues-isabel-joao-cons', 'da filha', 'cons')
# ('c1692-jose-cunha-isabel-rodrigues', '[ha mais de 6 anos,2 filhos,  amancebamento tipo "por conta"]', 'amanc')
# ('c1692-manuel-aires-domingas-luis', 'ela seria prima da mulher dele', 'amanci')
# ('c1692-manuel-catarina', 'manuel e catarina, 2102 e 2103, parentes em 4 grau', 'amanci')
# ('c1692-manuel-ferreira-juras', 'pela hostia sagrada', 'juras')
# ('c1692-manuel-mendes-maria-mendes', "desde 7 anos 'a mg. tirada a ela 28-5-1693", 'amanc')
# ('c1692-manuel-oliveira-pascoa', 'manuel de oliveira e pascoa, 2149 e 2150', 'amanc')
# ('c1692-manuel-pinto-domingas-roxa', 'portas adentro, ha 8 anos, tres filhos. Ja culpados anteriormente.', 'amanc')
# ('c1692-manuel-rodrigues-maria-joao', '4 grau.', 'amanci')
# ('c1692-maria-esteva', None, 'dev')
# ('c1692-maria-silva', None, 'dev')
# ('c1692-mateus-dias-curas', 'benzedor de gado e de pessoas com grandes cerimonias no cimo de um monte, ha quatro anos atras. margem: tiradas', 'curas')
# ('c1692-pai-de-joao-consentidor', 'nome desconhecido,2098a, descricao =do filho', 'cons')
# ('c1692-teresa-antonio-simoes', '4 grau de consaguinidade', 'amanci')
# ('c1694-antonio-joao-maria-rodrigues', 'antonio joao amancebado com maria rodrigues', 'amanc')
# ('c1694-antonio-vargas-consentidor', 'antonio vargas consentidor da filha', 'cons')
# ('c1694-d-pedro-antonia', 'd. pedro de soure com antonia', 'amanc')
# ('c1694-jose-bronze-maria-pereira', 'com filhos', 'amanc')
# ('c1694-jose-cunha-isabel-rodrigues', 'a mg."ille adm. in 2.o 1000 termo 3.o ella 2.o 800 termo 31"', 'amanc')
# ('c1694-jose-cunha-maria', None, 'amanc')
# ('c1694-manuel-marques-maria-pereira', 'nao e bem um amanc mais um caso de "intimidades", a mg.:"ele admoestado in 1.o termo 63"', 'amanc')
# ('c1698-alexandre-francisca', None, 'amanc')
# ('c1698-maria-folha-manuel', None, 'amanc')
# ('c1698-maria-ruiva', None, 'dev')
# ('c1705-catarina-leitao', '"""\n...espirita, falam os espiritos\n..dos mortos pela sua boca. Parece ser um caso tipico de relacao entre\n..interesses materiais familiares (herancas) e espritismo, provavelmente\n..relacionadas com transmissao de estatuto tambem.\n.."""', 'bruxa')
# ('c1705-manuel-joao-maria-batista', None, 'amanc')
# ('c1705-manuel-marques-ana', None, 'amanc')
# ('d1692-c13b', 'maria esteva,2093,de uma maria silva ou simoes a ruiva', 'alcov')
# ('d1692-c13c', 'maria esteva,2093,de uma maria silva ou simoes a ruiva', 'alcouc')
# ('d1692-c23', 'pascoa, 2150', 'dev')

# %%
print(repr(casos_table))
# Out:
# Table('casos', MetaData(), Column('id', String(length=Decimal('64')), ForeignKey('objects.id'), table=<casos>, primary_key=True, nullable=False), Column('obs', String(length=Decimal('16654')), table=<casos>), Column('the_type', String(length=Decimal('32')), table=<casos>), schema=None)

# %%
#see https://www.mail-archive.com/sqlalchemy@googlegroups.com/msg38030.html

pom_class_name = 'caso'
pom_class = session.query(PomSomMapper).get(pom_class_name)
pom_super_class = session.execute(select(PomSomMapper).where(PomSomMapper.id == pom_class.super_class)).scalars().one_or_none()
print(pom_super_class)

SuperORM = Entity.get_orm_for_pom_class(pom_super_class.id)

print(SuperORM)

props = {
    '__table__': casos_table,
    '__mapper_args__':{'polymorphic_identity':pom_class.id}
}

newORM = type(pom_class_name.capitalize(),(SuperORM,),props)
#Entity.registry.map_imperatively(newORM, casos_table,inherits=Object,polymorphic_identity=pom_class.id)
s = select(newORM)
print(s)
results = session.execute(s)
for c in results:
    print(c)
# Out:
# object table objects super entity
# object.id 	class id 	col id 	type varchar size 64 precision 0 primary key 1
# object.name 	class name 	col name 	type varchar size 64 precision 0 primary key 0
# object.obs 	class obs 	col obs 	type varchar size 16654 precision 0 primary key 0
# object.type 	class type 	col the_type 	type varchar size 32 precision 0 primary key 0
#
# <class '__main__.Object'>
# SELECT entities.class, casos.id, objects.id AS id_1, entities.id AS id_2, entities.inside, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.updated, entities.indexed, CASE WHEN (entities.class IN ([POSTCOMPILE_class_1])) THEN entities.class ELSE :param_1 END AS _sa_polymorphic_on, objects.name, casos.the_type, objects.the_type AS the_type_1, casos.obs, objects.obs AS obs_1
# FROM entities JOIN objects ON entities.id = objects.id JOIN casos ON objects.id = casos.id
# (Object(id=Entity(id="1708-c1", pom_class="caso",inside="1708-t1", the_order=9, the_level=4, the_line=24, groupname="caso", updated=2021-05-24 14:39:08 ... (36 characters truncated) ... e="None", the_type="violf", obs=na pronuncia sao setenciados a fazerem vida marital e ele a a tratar bem. pronuncia: admoestacao,resultado: fez termo),)
# (Object(id=Entity(id="1708-c2", pom_class="caso",inside="1708-t1", the_order=21, the_level=4, the_line=36, groupname="caso", updated=2021-05-24 14:39:08, indexed=2021-05-24 14:39:08,), name="None", the_type="nfvida", obs=None),)
# (Object(id=Entity(id="1708-c3", pom_class="caso",inside="1708-t8", the_order=96, the_level=4, the_line=108, groupname="caso", updated=2021-05-24 14:39:09, indexed=2021-05-24 14:39:09,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="1708-c4", pom_class="caso",inside="1708-t8", the_order=105, the_level=4, the_line=116, groupname="caso", updated=2021-05-24 14:39:09, indexed=2021-05-24 14:39:09,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="1708-c5", pom_class="caso",inside="1708-t8", the_order=110, the_level=4, the_line=121, groupname="caso", updated=2021-05-24 14:39:09, indexed=2021-05-24 14:39:09,), name="None", the_type="cons", obs=None),)
# (Object(id=Entity(id="1708-c6", pom_class="caso",inside="1708-t13", the_order=177, the_level=4, the_line=181, groupname="caso", updated=2021-05-24 14:39:09, indexed=2021-05-24 14:39:09,), name="None", the_type="ma lin", obs=None),)
# (Object(id=Entity(id="1708-c7", pom_class="caso",inside="1708-t26", the_order=335, the_level=4, the_line=328, groupname="caso", updated=2021-05-24 14:39:09, indexed=2021-05-24 14:39:09,), name="None", the_type="violf", obs=None),)
# (Object(id=Entity(id="1708-c8", pom_class="caso",inside="1708-t42", the_order=494, the_level=4, the_line=473, groupname="caso", updated=2021-05-24 14:39:09, indexed=2021-05-24 14:39:09,), name="None", the_type="ma lin", obs=None),)
# (Object(id=Entity(id="1708-c9", pom_class="caso",inside="1708-t44", the_order=526, the_level=4, the_line=504, groupname="caso", updated=2021-05-24 14:39:09, indexed=2021-05-24 14:39:09,), name="None", the_type="amanc", obs= ela casou-se em 21 de Fevereiro de 1707, ha' um ano e meio),)
# (Object(id=Entity(id="c1690-luisa-manrique-maria-simoes", pom_class="caso",inside="dev1690-per1-obj1", the_order=10, the_level=5, the_line=20, groupnam ... (151 characters truncated) ... vive longe do marido, numa casa por conta dele.
#                   Já acusados em visitas anteriores44relacao com muitos anos.
#
#                   """),)
# (Object(id=Entity(id="c1692-ana-simoes-feiticeira", pom_class="caso",inside="d1692-2114-obj137-20", the_order=1050, the_level=5, the_line=1140, groupname="caso", updated=2021-11-06 09:25:42, indexed=2021-11-06 09:25:42,), name="None", the_type="feitic", obs=ana simoes,2114a),)
# (Object(id=Entity(id="c1692-antonio-catarina-fernandes", pom_class="caso",inside="d1692-2052-obj57-20", the_order=412, the_level=5, the_line=450, group ... (44 characters truncated) ... dexed=2021-11-06 09:25:42,), name="None", the_type="amanc", obs=tiveram filho(a). 2.o a t.a 23 manuel goncalves, ele foi prezo por ordem do pai dela.),)
# (Object(id=Entity(id="c1692-antonio-cordeiro-alcouc", pom_class="caso",inside="dev1692-per1-obj1-20", the_order=14, the_level=5, the_line=29, groupname ... (27 characters truncated) ...  09:25:43, indexed=2021-11-06 09:25:43,), name="None", the_type="alcouc", obs=dava mulheres em casa. Margem: tirada de ambos 1.1.1691%1o. 8.bro 691. ),)
# (Object(id=Entity(id="c1692-antonio-gomes-maria", pom_class="caso",inside="d1692-2030-obj16-20", the_order=170, the_level=5, the_line=208, groupname="c ... (11 characters truncated) ... ed=2021-11-06 09:25:43, indexed=2021-11-06 09:25:43,), name="None", the_type="amanci", obs=quarto grau margem: tirada dela em 25.1.692 dele 14.5.1693),)
# (Object(id=Entity(id="c1692-antonio-simoes-maria-domingues", pom_class="caso",inside="d1692-2094-obj97-20", the_order=834, the_level=5, the_line=894, groupname="caso", updated=2021-11-06 09:25:43, indexed=2021-11-06 09:25:43,), name="None", the_type="cons", obs=da filha),)
# (Object(id=Entity(id="c1692-antonio-simoes-raposo-maria", pom_class="caso",inside="d1692-2094-obj94-20", the_order=774, the_level=5, the_line=832, groupname="caso", updated=2021-11-06 09:25:44, indexed=2021-11-06 09:25:44,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="c1692-baptista-moura-domingas-carvalho", pom_class="caso",inside="d1692-2139-obj166-20", the_order=1258, the_level=5, the_line=13 ... (30 characters truncated) ... 2021-11-06 09:25:44, indexed=2021-11-06 09:25:44,), name="None", the_type="amanci", obs=baptista de moura e isabel, 2140 e 2141 2.o grau de afinidade),)
# (Object(id=Entity(id="c1692-catarina-gaspar-curas", pom_class="caso",inside="dev1692-per5-obj7-20", the_order=116, the_level=5, the_line=154, groupname="caso", updated=2021-11-06 09:25:44, indexed=2021-11-06 09:25:44,), name="None", the_type="curas", obs=benze e cura de quebranto),)
# (Object(id=Entity(id="c1692-domingo-antunes-nfvida", pom_class="caso",inside="d1692-2073-obj68-20", the_order=570, the_level=5, the_line=608, groupname="caso", updated=2021-11-06 09:25:44, indexed=2021-11-06 09:25:44,), name="None", the_type="nfvida", obs=None),)
# (Object(id=Entity(id="c1692-joao-rodrigues-isabel-joao-cons", pom_class="caso",inside="d1692-2094-obj95-20", the_order=795, the_level=5, the_line=857, groupname="caso", updated=2021-11-06 09:25:44, indexed=2021-11-06 09:25:44,), name="None", the_type="cons", obs=da filha),)
# (Object(id=Entity(id="c1692-jose-cunha-isabel-rodrigues", pom_class="caso",inside="d1692-2052-obj57-20", the_order=396, the_level=5, the_line=434, grou ... (21 characters truncated) ... =2021-11-06 09:25:45, indexed=2021-11-06 09:25:45,), name="None", the_type="amanc", obs=[ha mais de 6 anos,2 filhos,  amancebamento tipo "por conta"]),)
# (Object(id=Entity(id="c1692-manuel-aires-domingas-luis", pom_class="caso",inside="dev1692-per5-obj7-20", the_order=122, the_level=5, the_line=160, groupname="caso", updated=2021-11-06 09:25:45, indexed=2021-11-06 09:25:45,), name="None", the_type="amanci", obs=ela seria prima da mulher dele),)
# (Object(id=Entity(id="c1692-manuel-catarina", pom_class="caso",inside="d1692-2101-obj107-20", the_order=884, the_level=5, the_line=954, groupname="caso", updated=2021-11-06 09:25:45, indexed=2021-11-06 09:25:45,), name="None", the_type="amanci", obs=manuel e catarina, 2102 e 2103, parentes em 4 grau),)
# (Object(id=Entity(id="c1692-manuel-ferreira-juras", pom_class="caso",inside="dev1692-per5-obj7-20", the_order=91, the_level=5, the_line=129, groupname="caso", updated=2021-11-06 09:25:45, indexed=2021-11-06 09:25:45,), name="None", the_type="juras", obs=pela hostia sagrada),)
# (Object(id=Entity(id="c1692-manuel-mendes-maria-mendes", pom_class="caso",inside="d1692-2060-obj58-20", the_order=443, the_level=5, the_line=481, group ... (1 characters truncated) ... ame="caso", updated=2021-11-06 09:25:46, indexed=2021-11-06 09:25:46,), name="None", the_type="amanc", obs=desde 7 anos 'a mg. tirada a ela 28-5-1693),)
# (Object(id=Entity(id="c1692-manuel-oliveira-pascoa", pom_class="caso",inside="d1692-2148-obj176-20", the_order=1359, the_level=5, the_line=1499, groupname="caso", updated=2021-11-06 09:25:46, indexed=2021-11-06 09:25:46,), name="None", the_type="amanc", obs=manuel de oliveira e pascoa, 2149 e 2150),)
# (Object(id=Entity(id="c1692-manuel-pinto-domingas-roxa", pom_class="caso",inside="dev1692-per5-obj7-20", the_order=99, the_level=5, the_line=137, group ... (25 characters truncated) ... -11-06 09:25:46, indexed=2021-11-06 09:25:46,), name="None", the_type="amanc", obs=portas adentro, ha 8 anos, tres filhos. Ja culpados anteriormente.),)
# (Object(id=Entity(id="c1692-manuel-rodrigues-maria-joao", pom_class="caso",inside="d1692-2069-obj66-20", the_order=517, the_level=5, the_line=555, groupname="caso", updated=2021-11-06 09:25:46, indexed=2021-11-06 09:25:46,), name="None", the_type="amanci", obs=4 grau.),)
# (Object(id=Entity(id="c1692-maria-esteva", pom_class="caso",inside="d1692-2092-obj92-20", the_order=749, the_level=5, the_line=808, groupname="caso", updated=2021-11-06 09:25:46, indexed=2021-11-06 09:25:46,), name="None", the_type="dev", obs=None),)
# (Object(id=Entity(id="c1692-maria-silva", pom_class="caso",inside="d1692-2092-obj93-20", the_order=760, the_level=5, the_line=819, groupname="caso", updated=2021-11-06 09:25:46, indexed=2021-11-06 09:25:46,), name="None", the_type="dev", obs=None),)
# (Object(id=Entity(id="c1692-mateus-dias-curas", pom_class="caso",inside="dev1692-per5-obj7-20", the_order=109, the_level=5, the_line=147, groupname="ca ... (62 characters truncated) ... ), name="None", the_type="curas", obs=benzedor de gado e de pessoas com grandes cerimonias no cimo de um monte, ha quatro anos atras. margem: tiradas),)
# (Object(id=Entity(id="c1692-pai-de-joao-consentidor", pom_class="caso",inside="d1692-2094-obj97-20", the_order=842, the_level=5, the_line=900, groupname="caso", updated=2021-11-06 09:25:47, indexed=2021-11-06 09:25:47,), name="None", the_type="cons", obs=nome desconhecido,2098a, descricao =do filho),)
# (Object(id=Entity(id="c1692-teresa-antonio-simoes", pom_class="caso",inside="d1692-2094-obj95-20", the_order=803, the_level=5, the_line=863, groupname="caso", updated=2021-11-06 09:25:47, indexed=2021-11-06 09:25:47,), name="None", the_type="amanci", obs=4 grau de consaguinidade),)
# (Object(id=Entity(id="c1694-antonio-joao-maria-rodrigues", pom_class="caso",inside="t1694-23-obj40", the_order=309, the_level=5, the_line=312, groupname="caso", updated=2021-11-06 09:25:47, indexed=2021-11-06 09:25:47,), name="None", the_type="amanc", obs=antonio joao amancebado com maria rodrigues),)
# (Object(id=Entity(id="c1694-antonio-vargas-consentidor", pom_class="caso",inside="t1694-13-obj23", the_order=199, the_level=5, the_line=203, groupname="caso", updated=2021-11-06 09:25:48, indexed=2021-11-06 09:25:48,), name="None", the_type="cons", obs=antonio vargas consentidor da filha),)
# (Object(id=Entity(id="c1694-d-pedro-antonia", pom_class="caso",inside="t1694-13-obj22", the_order=181, the_level=5, the_line=185, groupname="caso", updated=2021-11-06 09:25:48, indexed=2021-11-06 09:25:48,), name="None", the_type="amanc", obs=d. pedro de soure com antonia),)
# (Object(id=Entity(id="c1694-jose-bronze-maria-pereira", pom_class="caso",inside="t1694-1-obj2", the_order=28, the_level=5, the_line=33, groupname="caso", updated=2021-11-06 09:25:49, indexed=2021-11-06 09:25:49,), name="None", the_type="amanc", obs=com filhos),)
# (Object(id=Entity(id="c1694-jose-cunha-isabel-rodrigues", pom_class="caso",inside="t1694-3-obj5", the_order=61, the_level=5, the_line=65, groupname="ca ... (11 characters truncated) ... d=2021-11-06 09:25:49, indexed=2021-11-06 09:25:49,), name="None", the_type="amanc", obs=a mg."ille adm. in 2.o 1000 termo 3.o ella 2.o 800 termo 31"),)
# (Object(id=Entity(id="c1694-jose-cunha-maria", pom_class="caso",inside="t1694-3-obj5", the_order=75, the_level=5, the_line=79, groupname="caso", updated=2021-11-06 09:25:50, indexed=2021-11-06 09:25:50,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="c1694-manuel-marques-maria-pereira", pom_class="caso",inside="t1694-1-obj1", the_order=12, the_level=5, the_line=17, groupname="c ... (40 characters truncated) ... ed=2021-11-06 09:25:50,), name="None", the_type="amanc", obs=nao e bem um amanc mais um caso de "intimidades", a mg.:"ele admoestado in 1.o termo 63"),)
# (Object(id=Entity(id="c1698-alexandre-francisca", pom_class="caso",inside="t1698-1-obj1", the_order=12, the_level=5, the_line=17, groupname="caso", updated=2021-11-06 09:25:50, indexed=2021-11-06 09:25:50,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="c1698-maria-folha-manuel", pom_class="caso",inside="t1698-1-obj2", the_order=27, the_level=5, the_line=32, groupname="caso", updated=2021-11-06 09:25:51, indexed=2021-11-06 09:25:51,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="c1698-maria-ruiva", pom_class="caso",inside="t1698-6-obj7", the_order=81, the_level=5, the_line=86, groupname="caso", updated=2021-11-06 09:25:51, indexed=2021-11-06 09:25:51,), name="None", the_type="dev", obs=None),)
# (Object(id=Entity(id="c1705-catarina-leitao", pom_class="caso",inside="1705-t35-obj35", the_order=223, the_level=5, the_line=259, groupname="caso", upd ... (179 characters truncated) ... co de relacao entre
# ..interesses materiais familiares (herancas) e espritismo, provavelmente
# ..relacionadas com transmissao de estatuto tambem.
# .."""),)
# (Object(id=Entity(id="c1705-manuel-joao-maria-batista", pom_class="caso",inside="1705-t31-obj31", the_order=174, the_level=5, the_line=188, groupname="caso", updated=2021-11-06 09:25:51, indexed=2021-11-06 09:25:51,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="c1705-manuel-marques-ana", pom_class="caso",inside="1705-t26-obj26", the_order=113, the_level=5, the_line=127, groupname="caso", updated=2021-11-06 09:25:52, indexed=2021-11-06 09:25:52,), name="None", the_type="amanc", obs=None),)
# (Object(id=Entity(id="d1692-c13b", pom_class="caso",inside="d1692-2123-obj149-20", the_order=1148, the_level=5, the_line=1238, groupname="caso", updated=2021-11-06 09:25:52, indexed=2021-11-06 09:25:52,), name="None", the_type="alcov", obs=maria esteva,2093,de uma maria silva ou simoes a ruiva),)
# (Object(id=Entity(id="d1692-c13c", pom_class="caso",inside="d1692-2123-obj149-20", the_order=1153, the_level=5, the_line=1242, groupname="caso", updated=2021-11-06 09:25:52, indexed=2021-11-06 09:25:52,), name="None", the_type="alcouc", obs=maria esteva,2093,de uma maria silva ou simoes a ruiva),)
# (Object(id=Entity(id="d1692-c23", pom_class="caso",inside="d1692-2148-obj176-20", the_order=1375, the_level=5, the_line=1515, groupname="caso", updated=2021-11-06 09:25:52, indexed=2021-11-06 09:25:52,), name="None", the_type="dev", obs=pascoa, 2150),)
# /var/folders/sx/x6pyh9097n98mlz29_6njdj00000gn/T/ipykernel_63215/1205763381.py:17: SAWarning: Implicitly combining column objects.obs with column casos.obs under attribute 'obs'.  Please configure one or more attributes for these same-named columns explicitly.
#   newORM = type(pom_class_name.capitalize(),(SuperORM,),props)
# /var/folders/sx/x6pyh9097n98mlz29_6njdj00000gn/T/ipykernel_63215/1205763381.py:17: SAWarning: Implicitly combining column objects.the_type with column casos.the_type under attribute 'the_type'.  Please configure one or more attributes for these same-named columns explicitly.
#   newORM = type(pom_class_name.capitalize(),(SuperORM,),props)

# %%
newORM.__mapper_args__
# Out:
# {'polymorphic_identity': 'caso'}

# %%
for mapper in Entity.registry.mappers:
    print(f' Table {mapper.local_table} is mapped to {mapper.class_} through entities.class={mapper.polymorphic_identity}')
# Out:
#  Table persons is mapped to <class '__main__.Person'> through entities.class=person
#  Table class_attributes is mapped to <class '__main__.PomClassAttributes'> through entities.class=None
#  Table entities is mapped to <class '__main__.Entity'> through entities.class=entity
#  Table objects is mapped to <class '__main__.Object'> through entities.class=object
#  Table classes is mapped to <class '__main__.PomSomMapper'> through entities.class=class
#  Table relations is mapped to <class '__main__.Relation'> through entities.class=relation
#  Table attributes is mapped to <class '__main__.Attribute'> through entities.class=attribute
#  Table casos is mapped to <class '__main__.Caso'> through entities.class=caso
#  Table sources is mapped to <class '__main__.Source'> through entities.class=source
#  Table acts is mapped to <class '__main__.Act'> through entities.class=act

# %%
print(Entity.mapped_pom_classes())
# Out:
# ['attribute', 'relation', 'person', 'object', 'act', 'source', 'class']

# %%
print("Dictionnary for mapping table to ORM classes")
table_to_orm= {subclass.__mapper__.local_table.name:subclass for subclass in Entity.get_subclasses()}
print(table_to_orm)
print("Dictionnary for mapping pom_class to ORM classes")
pom_class_to_orm= {subclass.__mapper__.polymorphic_identity:subclass for subclass in Entity.get_subclasses()}
print(pom_class_to_orm)
# Out:
# Dictionnary for mapping table to ORM classes
# {'attributes': <class '__main__.Attribute'>, 'relations': <class '__main__.Relation'>, 'persons': <class '__main__.Person'>, 'casos': <class '__main__.Caso'>, 'objects': <class '__main__.Object'>, 'acts': <class '__main__.Act'>, 'sources': <class '__main__.Source'>, 'classes': <class '__main__.PomSomMapper'>}
# Dictionnary for mapping pom_class to ORM classes
# {'attribute': <class '__main__.Attribute'>, 'relation': <class '__main__.Relation'>, 'person': <class '__main__.Person'>, 'caso': <class '__main__.Caso'>, 'object': <class '__main__.Object'>, 'act': <class '__main__.Act'>, 'source': <class '__main__.Source'>, 'class': <class '__main__.PomSomMapper'>}

# %%
Caso.__mapper__.local_table.name
# Out:
# 'objects'

# %% [markdown]
# ### Next steps
#
# * Entity new methods
#     * get_orm_for_table(table): return table_to_orm.get(table,None)
#     * get_orm_for_pom_class(pom_class) return pom_class_to_orm.get(pom_class,None)
#
# * PomToSom generate table done above refactor as method
#     * newtable= blah blah
#     * if id=entity exit
#     * BaseForThis = Entity.get_orm_for_pom_class(self.super_class)
#     * Use Type to create empty class extending BaseForthis into NewORM
#     * Entity.registry.map_imperatively(NewORM, newTable)
#     * set the polymorphic_identity of newTable = self.id HOW? just set __mapper_args__?
#
#
# We can check if the new table needs to be created
#
#     # The recommended way to check for existence
#     sqlalchemy.inspect(engine).has_table("BOOKS")

# %%
result=session.query(PomSomMapper.id,PomSomMapper.super_class).all()
print(result)
# Out:
# [('act', 'entity'), ('acta', 'act'), ('acusacoes', 'object'), ('aforamento', 'good'), ('attribute', 'entity'), ('cartaperdao', 'act'), ('caso', 'object'), ('class', 'entity'), ('crime', 'object'), ('divida', 'object'), ('entity', 'root'), ('escritura', 'act'), ('geoentity', 'entity'), ('good', 'object'), ('group_element', 'entity'), ('item', 'object'), ('lgraph', 'entity'), ('object', 'entity'), ('person', 'entity'), ('relation', 'entity'), ('rgeoentity', 'rentity'), ('robject', 'rentity'), ('rperson', 'rentity'), ('source', 'entity')]

# %% [markdown]
# ## Testing handling of missing mappings

# %%
C = PomSomMapper.find_pom_class(session, 'acta')
print(C)
# Out:
# act

# %%
acta = session.query(Act).where(Entity.pom_class  == 'acta').first()

print(repr(acta))
print(acta)
# Out:
# Act(id=Entity(id="amz1", pom_class="acta",inside="mis-mesa-1", the_order=2, the_level=2, the_line=6, groupname="amz", updated=2021-11-01 04:22:41, indexed=2021-11-01 04:22:41,), the_type="amz", the_date="16831003", local="None", ref="None", obs=None)
# amz$amz1/16831003/type=amz/ref=None/loc=None

# %%
classes_from_entities = session.query(Entity.pom_class.distinct()).all()
print(classes_from_entities)
# Out:
# [('act',), ('acta',), ('acusacoes',), ('aforamento',), ('aregister',), ('attribute',), ('cartaperdao',), ('caso',), ('class',), ('crime',), ('divida',), ('escritura',), ('geoentity',), ('good',), ('group_element',), ('item',), ('object',), ('person',), ('relation',), ('rperson',), ('source',)]

# %%
print(Entity.__subclasses__())
for aclass in Entity.__subclasses__():
    print(aclass.__tablename__)
# Out:
# [<class '__main__.Attribute'>, <class '__main__.Relation'>, <class '__main__.Person'>, <class '__main__.Object'>, <class '__main__.Act'>, <class '__main__.Source'>, <class '__main__.PomClass'>]
# attributes
# relations
# persons
# objects
# acts
# sources
# classes

# %%
from sqlalchemy import select
from sqlalchemy.orm import Session

stmt = select(Person).first()
print(stmt)
with Session(engine) as session:
    for row in session.execute(stmt):
        entity: Entity=row[0]
        print(f'{entity.groupname}${entity.name}/id={entity.id}#{entity.pom_class}')
        for attribute in entity.attributes:
            print(f'     ls${attribute.the_type}/{attribute.the_value}/{attribute.the_date}',end='')
            if attribute.obs is not None:
                print(f'/obs={attribute.obs}')
            else:
                print()
        if len(entity.rels_out)>0:
            for rel in entity.rels_out:
                print(f'>{rel}')
        if len(entity.rels_in)>0:
            for rel in entity.rels_in:
                    print(rel,'<')
# Out:
# SELECT entities.class, persons.id, entities.id AS id_1, entities.inside, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.updated, entities.indexed, persons.name, persons.sex, persons.obs
# FROM entities JOIN persons ON entities.id = persons.id
# WHERE persons.id = :id_2
# n$Arnaldo Henriques de Abreu/id=140625#person
#      ls$código-de-referência/"PT/AUC/ELU/UC-AUC/B/001-001/A/000336"/20200211
#      ls$data-do-registo/2018-04-19 14:33:58/20200211
#      ls$url/"https://pesquisa.auc.uc.pt/details?id=140625"/20200211
#      ls$uc.entrada/1835-10-17/1835-10-17
#      ls$uc.saida/1838-10-09/1838-10-09
#      ls$uc.entrada.ano/1835/1835-10-17
#      ls$uc.saida.ano/1838/1838-10-09
#      ls$nome/Arnaldo Henriques de Abreu/1835-10-17
#      ls$nome.primeiro/Arnaldo/1835-10-17
#      ls$nome.apelido/Henriques de Abreu/1835-10-17
#      ls$nome.apelido/Abreu/1835-10-17
#      ls$naturalidade/Porto/1835-10-17
#      ls$naturalidade.ano/Porto.1835/1835-10-17
#      ls$nome-geografico/Porto/1835-10-17
#      ls$nome-geografico.ano/Porto.1835/1835-10-17
#      ls$faculdade/Matemática/1835-10-17
#      ls$faculdade.ano/Matemática.1835/1835-10-17
#      ls$matricula/Matemática/1835-10-17/obs="1835/10/17 (obrigado)"
#      ls$matricula.ano/Matemática.1835/1835-10-17/obs="1835/10/17 (obrigado)"
#      ls$matricula/Matemática/1835-10-17/obs="1835/10/17 (obrigado)"
#      ls$matricula.ano/Matemática.1835/1835-10-17/obs="1835/10/17 (obrigado)"
#      ls$matricula/Matemática/1838-10-09/obs="1838/10/09"
#      ls$matricula.ano/Matemática.1838/1838-10-09/obs="1838/10/09"
# >     rel$function-in-act/n/auc-alumni-A-140337-140771/20200211

# %% [markdown]
# ## Source files

# %%
from pathlib import Path

kleio_files = [f.stem for f in list(Path('../sources').rglob('*.cli'))]
print("Number of kleio_files:", len(kleio_files))

imported_sources = %sql select sources.id, sources.kleiofile, entities.updated from sources left join entities on (sources.id=entities.id) order by updated desc 
sources_in_db = [s.id for s in imported_sources]
print("Number of imported files:",len(sources_in_db))

print("Files not in the database:", set(kleio_files)-set(sources_in_db))
print("Imported sources no file found:", set(sources_in_db)-set(kleio_files))
# Out:
# Number of kleio_files: 235
# 235 rows affected.
# Number of imported files: 235
# Files not in the database: set()
# Imported sources no file found: set()

# %% [markdown]
# ## Analyse attributes extracted from records

# %% [markdown]
# ### Attributes in the database

# %%
nml = %sql select the_type, count(*) as tot from attributes group by the_type
for the_type, tot in nml:
    print(f'{tot:6} | {the_type}')
# Out:
# 28 rows affected.
# 105300 | código-de-referência
#    275 | colegio
# 105300 | data-do-registo
#    186 | ec
#  53627 | exame
#  94164 | faculdade
#  94164 | faculdade.ano
# 106372 | grau
# 106372 | grau.ano
# 319291 | matricula
# 319291 | matricula.ano
#  98904 | naturalidade
#  98904 | naturalidade.ano
# 105300 | nome
# 107486 | nome-geografico
# 101392 | nome-geografico.ano
# 198660 | nome.apelido
# 105300 | nome.primeiro
#   8155 | nome.vide
#   9975 | nota
#   3142 | ordem-religiosa
#   7036 | padre
#   4170 | titulo
# 105300 | uc.entrada
#  99014 | uc.entrada.ano
# 105300 | uc.saida
#  99281 | uc.saida.ano
# 105300 | url

# %%
p1540 = %sql select id, name, pobs from nattributes where the_type='uc.entrada' and the_value like '1540%'
for id, name, pobs in p1540:
    print(f'{id:5} | {name} \n {pobs}\n\n')
# Out:
# 473 rows affected.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_428226/4098037847.py in <module>
#       1 p1540 = get_ipython().run_line_magic('sql', "select id, name, pobs from nattributes where the_type='uc.entrada' and the_value like '1540%'")
#       2 for id, name, pobs in p1540:
# ----> 3     print(f'{id:r} | {name} \n {pobs}\n\n')
#
# ValueError: Unknown format code 'r' for object of type 'str'
